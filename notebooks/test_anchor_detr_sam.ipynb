# %%
import sys
import_dir = '/home/icb/lion.gleiter/projects/organoid_sam/external'
if import_dir not in sys.path:
    sys.path.append(import_dir)
import_dir = '/home/icb/lion.gleiter/projects/organoid_sam/segment-anything/segment-anything'
if import_dir not in sys.path:
    sys.path.append(import_dir)
from models.samos_anchor_detr import DetectionTransformer

import hydra
import models.image_datamodule

from train_general import initialize_model_and_dataset, train

# %load_ext autoreload
# %autoreload 2

# %%
# Load hydra configuration in jupyter notebook
hydra.initialize_config_dir(
    config_dir='/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/configs'
)
# Out:
# /tmp/ipykernel_370139/4172709858.py:2: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   hydra.initialize_config_dir(
# hydra.initialize_config_dir()

# %%
cfg = hydra.compose(
    config_name='default',
    overrides=[
        # '+baseline_models=anchor_detr',
        # '+baseline_models=anchor_detr_frozen_resnet50',
        '+baseline_models=anchor_detr_sam_base',
        # '+baseline_models=anchor_detr_sam_large',
        # 'model=anchor_detr',
        # 'model.backbone=vit_b',
        # 'model.num_queries=100',
        # 'model.num_classes=1',
        # 'model.aux_loss=True',
        # 'model.dilation=False',
        # 'model.use_samos=True',
        # 'model.samos_anchor_detr.use_samos_anchor=True',
        # 'model.samos_anchor_detr.use_samos_decoder=True',
        # 'model.samos_anchor_detr.use_samos_encoder=True',
        # 'model.samos_anchor_detr.use_samos_loss=True',
        # 'model.samos_anchor_detr.use_samos_postprocess=True'
        
        'sub_name=debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24',
        'num_query_position=300',
        'focal_alpha=0.9',
        'sampling_groups=["n_objects"]',
        'seed=2024',
        'train_dirs=["NeurIPSCellSeg_train"]', 
        'val_dirs=["NeurIPSCellSeg_val"]',
        'lr_drop=10000',
        'max_epochs=100',
        'test_dirs=[]',
        'batch_size=4',
        'accumulate_grad_batches=6',
        'cache_10_samples=false',
    ]
)
cfg
# Out:
# {'train_dirs': ['NeurIPSCellSeg_train'], 'val_dirs': ['NeurIPSCellSeg_val'], 'test_dirs': [], 'decoder': 'AnchorDETR', 'backbone_name': '${backbone}', 'freeze_backbone': True, 'trace_compute': False, 'memory_snapshot': False, 'cache_10_samples': False, 'seed': 2024, 'accumulate_grad_batches': 6, 'batch_size': 4, 'batches_per_epoch': 100, 'max_epochs': 100, 'use_sampler': True, 'sampling_groups': ['n_objects'], 'max_oversampling': 10.0, 'n_validation_samples': 40, 'gradient_clip_val': 0.1, 'checkpoint_path': None, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lr_drop': 10000, 'project_name': 'OrganoidDetection', 'sub_name': 'debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24', 'log_dir': 'logs/', 'backbone': 'SAM_base_images', 'backbone_get_intermediate_layers': [2, 5], 'num_feature_levels': 3, 'backbone_model_size': 'base', 'dilation': True, 'finetune_only_class_linear': False, 'num_classes': 1, 'lr_backbone_names': ['backbone'], 'lr_backbone': 1e-05, 'frozen_weights': None, 'enc_layers': 6, 'dec_layers': 6, 'dim_feedforward': 1024, 'hidden_dim': 256, 'dropout': 0.0, 'nheads': 8, 'num_query_position': 300, 'num_query_pattern': 3, 'spatial_prior': 'learned', 'attention_type': 'RCDA', 'masks': False, 'aux_loss': True, 'set_cost_class': 2, 'set_cost_bbox': 5, 'set_cost_giou': 2, 'mask_loss_coef': 1, 'dice_loss_coef': 1, 'cls_loss_coef': 2, 'bbox_loss_coef': 5, 'giou_loss_coef': 2, 'focal_alpha': 0.9, 'device': 'cuda'}

# %%
import wandb

train_dirs_str = "_".join(cfg.train_dirs)
wandb.init(project=f"test_anchor_detr", name=f"{cfg.project_name}_{cfg.decoder}_{cfg.backbone_name}_{train_dirs_str}_{cfg.sub_name}_{cfg.seed}")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lgle (cpfe). Use `wandb login --relogin` to force relogin
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/cpfe/test_anchor_detr/runs/u215kd0o?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
train(cfg)
# Out:
# [rank: 0] Seed set to 2024
# Training Parameters:
# _metadata: ContainerMetadata(ref_type=typing.Any, object_type=<class 'dict'>, optional=True, key=None, flags={'struct': True}, flags_root=False, resolver_cache=defaultdict(<class 'dict'>, {'now': {('%Y-%m-%d',): '2025-06-18', ('%H-%M-%S',): '19-07-09'}}), key_type=typing.Any, element_type=typing.Any)
# _parent: None
# _flags_cache: {'struct': True}
# _content: {'train_dirs': ['NeurIPSCellSeg_train'], 'val_dirs': ['NeurIPSCellSeg_val'], 'test_dirs': [], 'decoder': 'AnchorDETR', 'backbone_name': '${backbone}', 'freeze_backbone': True, 'trace_compute': False, 'memory_snapshot': False, 'cache_10_samples': False, 'seed': 2024, 'accumulate_grad_batches': 6, 'batch_size': 4, 'batches_per_epoch': 100, 'max_epochs': 100, 'use_sampler': True, 'sampling_groups': ['n_objects'], 'max_oversampling': 10.0, 'n_validation_samples': 40, 'gradient_clip_val': 0.1, 'checkpoint_path': None, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lr_drop': 10000, 'project_name': 'OrganoidDetection', 'sub_name': 'debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24', 'log_dir': 'logs/', 'backbone': 'SAM_base_images', 'backbone_get_intermediate_layers': [2, 5], 'num_feature_levels': 3, 'backbone_model_size': 'base', 'dilation': True, 'finetune_only_class_linear': False, 'num_classes': 1, 'lr_backbone_names': ['backbone'], 'lr_backbone': 1e-05, 'frozen_weights': None, 'enc_layers': 6, 'dec_layers': 6, 'dim_feedforward': 1024, 'hidden_dim': 256, 'dropout': 0.0, 'nheads': 8, 'num_query_position': 300, 'num_query_pattern': 3, 'spatial_prior': 'learned', 'attention_type': 'RCDA', 'masks': False, 'aux_loss': True, 'set_cost_class': 2, 'set_cost_bbox': 5, 'set_cost_giou': 2, 'mask_loss_coef': 1, 'dice_loss_coef': 1, 'cls_loss_coef': 2, 'bbox_loss_coef': 5, 'giou_loss_coef': 2, 'focal_alpha': 0.9, 'device': 'cuda'}
# features {'blocks.2': 'intermediate_2', 'blocks.5': 'intermediate_5', 'neck': 'final_embed'}
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loggers/wandb.py:396: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /ictstr01/home/icb/lion.gleiter/projects/organoid_sa ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 23172it [00:01, 12235.66it/s]
# len(train_dataset) 23172
# 3029it [00:00, 15618.62it/s]
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /ictstr01/groups/shared/users/lion.gleiter/organoid_sam/checkpoints_trained_miccai/AnchorDETR_SAM_base_images_NeurIPSCellSeg_train_debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24_True_4_100_2024 exists and is not empty.
# Restoring states from the checkpoint path at /ictstr01/groups/shared/users/lion.gleiter/organoid_sam/checkpoints_trained_miccai/AnchorDETR_SAM_base_images_NeurIPSCellSeg_train_debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24_True_4_100_2024/AnchorDETR_SAM_base_images_NeurIPSCellSeg_train_debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24_True_4_100_2024-last.ckpt
# len(val_datasets) [3029]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type                 | Params | Mode
# ------------------------------------------------------------------
# 0 | model            | DetectionTransformer | 103 M  | train
# 1 | val_giou_metrics | ModuleList           | 0      | train
# 2 | val_map_metrics  | ModuleList           | 0      | train
# ------------------------------------------------------------------
# 14.3 M    Trainable params
# 89.7 M    Non-trainable params
# 103 M     Total params
# 415.819   Total estimated model params size (MB)
# 204       Modules in train mode
# 171       Modules in eval mode
# Restored all states from the checkpoint at /ictstr01/groups/shared/users/lion.gleiter/organoid_sam/checkpoints_trained_miccai/AnchorDETR_SAM_base_images_NeurIPSCellSeg_train_debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24_True_4_100_2024/AnchorDETR_SAM_base_images_NeurIPSCellSeg_train_debug_ce_loss_focal_alpha_09_sam_base_full_dataloading_300queries_bs24_True_4_100_2024-last.ckpt
# Num trainable params (total): 14283869
# Num trainable params (backbone): 0
# Sanity Checking: |                                                                                      | 0/? [00:00<?, ?it/s]
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:475: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# Sanity Checking DataLoader 0:   0%|                                                                     | 0/2 [00:00<?, ?it/s]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: Encountered more than 100 detections in a single image. This means that certain detections with the lowest scores will be ignored, that may have an undesirable impact on performance. Please consider adjusting the `max_detection_threshold` to suit your use case. To disable this warning, set attribute class `warn_on_many_detections=False`, after initializing the metric.
#   warnings.warn(*args, **kwargs)
# torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Sanity Checking DataLoader 0:  50%|██████████████████████████████▌                              | 1/2 [00:04<00:04,  0.20it/s]
# /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 3. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  37%|████████████████████████▊                                          | 37/100 [00:56<01:36,  0.65it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  38%|█████████████████████████▍                                         | 38/100 [00:58<01:35,  0.65it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  39%|██████████████████████████▏                                        | 39/100 [00:59<01:33,  0.65it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  40%|██████████████████████████▊                                        | 40/100 [01:01<01:31,  0.66it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  41%|███████████████████████████▍                                       | 41/100 [01:02<01:29,  0.66it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  42%|████████████████████████████▏                                      | 42/100 [01:03<01:27,  0.66it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  43%|████████████████████████████▊                                      | 43/100 [01:04<01:25,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  44%|█████████████████████████████▍                                     | 44/100 [01:05<01:23,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  45%|██████████████████████████████▏                                    | 45/100 [01:07<01:22,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  46%|██████████████████████████████▊                                    | 46/100 [01:08<01:20,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  47%|███████████████████████████████▍                                   | 47/100 [01:09<01:18,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  48%|████████████████████████████████▏                                  | 48/100 [01:11<01:17,  0.67it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  49%|████████████████████████████████▊                                  | 49/100 [01:12<01:15,  0.68it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  50%|█████████████████████████████████▌                                 | 50/100 [01:13<01:13,  0.68it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# ...
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  59%|███████████████████████████████████████▌                           | 59/100 [01:24<00:59,  0.69it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  60%|████████████████████████████████████████▏                          | 60/100 [01:26<00:57,  0.70it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  61%|████████████████████████████████████████▊                          | 61/100 [01:27<00:55,  0.70it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  62%|█████████████████████████████████████████▌                         | 62/100 [01:28<00:54,  0.70it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  63%|██████████████████████████████████████████▏                        | 63/100 [01:29<00:52,  0.70it/s, v_num=kd0o]torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# Epoch 9:  64%|██████████████████████████████████████████▉                        | 64/100 [01:30<00:51,  0.71it/s, v_num=kd0o]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# torch.float32
# torch.Size([4, 3, 1024, 1024])
# x.min(), x.max() tensor(-2.1179, device='cuda:0') tensor(2.2489, device='cuda:0')
# x.min(), x.max() tensor(-2.0357, device='cuda:0') tensor(2.4286, device='cuda:0')
# x.min(), x.max() tensor(-1.8044, device='cuda:0') tensor(2.6400, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:205, in _FitLoop.run(self)
#     204 self.on_advance_start()
# --> 205 self.advance()
#     206 self.on_advance_end()
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:363, in _FitLoop.advance(self)
#     362 assert self._data_fetcher is not None
# --> 363 self.epoch_loop.run(self._data_fetcher)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:140, in _TrainingEpochLoop.run(self, data_fetcher)
#     139 try:
# --> 140     self.advance(data_fetcher)
#     141     self.on_advance_end(data_fetcher)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:250, in _TrainingEpochLoop.advance(self, data_fetcher)
#     248 if trainer.lightning_module.automatic_optimization:
#     249     # in automatic optimization, there can only be one optimizer
# --> 250     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     251 else:
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py:183, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     182     with _block_parallel_sync_behavior(self.trainer.strategy, block=True):
# --> 183         closure()
#     185 # ------------------------------
#     186 # BACKWARD PASS
#     187 # ------------------------------
#     188 # gradient update with accumulated gradients
#     189 else:
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py:144, in Closure.__call__(self, *args, **kwargs)
#     142 @override
#     143 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 144     self._result = self.closure(*args, **kwargs)
#     145     return self._result.loss
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py:129, in Closure.closure(self, *args, **kwargs)
#     126 @override
#     127 @torch.enable_grad()
#     128 def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 129     step_output = self._step_fn()
#     131     if step_output.closure_loss is None:
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py:317, in _AutomaticOptimization._training_step(self, kwargs)
#     315 trainer = self.trainer
# --> 317 training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     318 self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:319, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     318 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 319     output = fn(*args, **kwargs)
#     321 # restore current_fx when nested context
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/strategies/strategy.py:390, in Strategy.training_step(self, *args, **kwargs)
#     389     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 390 return self.lightning_module.training_step(*args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/models/training_module.py:92, in TrainingModule.training_step(self, batch, batch_idx)
#      91 self.model.train()
# ---> 92 total_loss, loss_dict, metrics_dict = self.model.forward_train(batch)
#      93 self.log('train_loss', total_loss, on_step=False, on_epoch=True)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/models/samos_anchor_detr.py:329, in DetectionTransformer.forward_train(self, batch)
#     328 self.train()
# --> 329 return self.forward_batch(batch)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/models/samos_anchor_detr.py:280, in DetectionTransformer.forward_batch(self, batch)
#     277 # print('targets_updated', targets_updated[0]['boxes'])
#     278
#     279 # Forward
# --> 280 outputs = self.model(images)
#     282 # Loss
#     283 # print('outputs', outputs)
#     284 # print('targets', targets_updated)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File ~/projects/organoid_sam/external/AnchorDETR/models/anchor_detr.py:99, in AnchorDETR.forward(self, samples)
#      98 # print('before backbone', time.time())
# ---> 99 features = self.backbone(samples)
#     100 # print('after backbone', time.time())
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/models/samos_anchor_detr.py:123, in SAMBackbone.forward(self, x)
#     122 print('x.min(), x.max()', x[:,2,:,:].min(), x[:,2,:,:].max())
# --> 123 feats = self.sam(x)
#     124 outputs = []
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/fx/graph_module.py:784, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     783 def call_wrapped(self, *args, **kwargs):
# --> 784     return self._wrapped_call(self, *args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/fx/graph_module.py:348, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     347     else:
# --> 348         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     349 except Exception as e:
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#
# File <eval_with_key>.17 from /home/icb/lion.gleiter/projects/organoid_sam/segment-anything/segment-anything/segment_anything/modeling/image_encoder.py:106 in forward:203, in forward(self, x)
#     202 get_rel_pos_6 = segment_anything_modeling_image_encoder_get_rel_pos(getitem_49, getitem_49, blocks_3_attn_rel_pos_h);  blocks_3_attn_rel_pos_h = None
# --> 203 get_rel_pos_7 = segment_anything_modeling_image_encoder_get_rel_pos(getitem_50, getitem_50, blocks_3_attn_rel_pos_w);  blocks_3_attn_rel_pos_w = None
#     204 getattr_14 = getitem_52.shape
#
# File ~/projects/organoid_sam/segment-anything/segment-anything/segment_anything/modeling/image_encoder.py:292, in get_rel_pos(q_size, k_size, rel_pos)
#     289     return x
# --> 292 def get_rel_pos(q_size: int, k_size: int, rel_pos: torch.Tensor) -> torch.Tensor:
#     293     """
#     294     Get relative positional embeddings according to the relative positions of
#     295         query and key sizes.
#    (...)    302         Extracted positional embeddings according to relative positions.
#     303     """
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train(cfg)
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head/train_general.py:213, in train(args)
#     202 lr_monitor = LearningRateMonitor(logging_interval="epoch", log_momentum=False)
#     204 trainer = pl.Trainer(
#     205     logger=[wandb_logger],
#     206     callbacks=[checkpoint_callback_last, checkpoint_callback_best, lr_monitor],
#    (...)    210     accumulate_grad_batches=args.accumulate_grad_batches,
#     211 )
# --> 213 trainer.fit(model, data_module, ckpt_path=ckpt_file_resume)
#     215 if args.memory_snapshot:
#     216     snapshot_file = 'memory_run_1'
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File /ictstr01/home/icb/lion.gleiter/projects/organoid_sam/venvs/anchor_detr/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
wandb.finish()
# Out:
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
