# %% [markdown]
# # Compute metrics
#
# F1, recall, precision, mean IoU, mean Dice, PQ
#
# Save metrics as:
#
# results/experiment_metrics.csv

# %%
1+1
# Out:
# 2

# %%
import numpy as np
import cv2
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from copy import deepcopy
import skimage
import scipy
import basicpy
from tqdm import tqdm

import sys
sys.path.append('/home/icb/lion.gleiter/projects/organoid_sam/SAM_with_Detection_Head')

from util.box_ops_numpy import mask_to_boxes, cxcywh_to_xyxy, xyxy_to_cxcywh, plot_boxes
from util import dataloading as dl
from util import postprocessing as pp

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_datadir = Path('/ictstr01/groups/shared/users/lion.gleiter/organoid_sam/original_data/')
results_dir = Path('/ictstr01/groups/shared/users/lion.gleiter/organoid_sam/results')
# organoid_sam = Path('/ictstr01/groups/shared/users/lion.gleiter/organoid_sam')

# %%
ds = dl.OrgaSegment(split='test')
im, mask, boxes, im_path, im_ID = ds[0]
im, flatfield = dl.normalize(im)

plot_boxes(im, boxes, format='yxyx_px')

# %%
ds = dl.NewData(split='train')
im, mask, boxes, im_path, im_ID = ds[5]
im, flatfield = dl.normalize(im)

plot_boxes(im, boxes, format='yxyx_px')

# %%
ds = dl.NewData(split='train')
im, mask, boxes, im_path, im_ID = ds[17]
im, flatfield = dl.normalize(im)

plot_boxes(im, boxes, format='yxyx_px')

# %%
ds = dl.NewData(split='train')
im, mask, boxes, im_path, im_ID = ds[13]
im, flatfield = dl.normalize(im)

plot_boxes(im, boxes, format='yxyx_px')

# %%
ds = dl.OrganoID(split='test')
im, mask, boxes, im_path, im_ID = ds[3]
im, flatfield = dl.normalize(im)

plot_boxes(im, boxes, format='yxyx_px')

# %%
# import detection_head_datamodule_copy as dhdm

# %%
# data_module = DetectionHeadDataModule(
#                                         encoder_name='SAM_large', 
#                                         batch_size=32, 
#                                         train_dir_names=['OrganoID_train', 'MultiOrg_train_macros', 'MultiOrg_train_normal', 'OrgaExtractor_train', 'OrgaQuant_train', 'OrgaSegment_train', 'Tellu_train'],
#                                         val_dir_names=['OrganoID_val', 'MultiOrg_test_macros', 'MultiOrg_test_normal', 'OrgaExtractor_test', 'OrgaQuant_test', 'OrgaSegment_val', 'Tellu_val'],
#                                         batches_per_epoch=args.batches_per_epoch,
#                                         use_sampler=args.use_sampler,
#                                         balance_datasets=args.balance_datasets,
#                                         balance_validation=args.balance_validation,
#                                         balance_newdata=args.balance_newdata
#                                         )

# %%
split = 'test'
pred_folder = Path(f'/ictstr01/groups/shared/users/lion.gleiter/organoid_sam/patch_predictions/SAM_large/{split}/{str(ds)}_{ds.split}/DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_5_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.28')
pred_boxes, pred_scores, pred_masks, pred_patch_numbers, pred_offsets = pp.get_predictions(split, f'{str(ds)}_{ds.split}', pred_folder, im, im_ID)

# %%
pred_masks.shape
# Out:
# (400, 1024, 1024)

# %%
(pred_masks.sum(axis=(1, 2)) < 100).sum()
# Out:
# 22

# %%
plt.imshow(im)
plt.imshow(np.any(pred_masks[pred_scores > 0.96], axis=0).astype(int) * 255, alpha=0.5, cmap='YlGn')

# %%
plt.imshow(im)
plt.imshow((mask >=1).astype(int) * 255, alpha=0.5, cmap='YlGn')

# %%
plt.imshow(np.any(pred_masks, axis=0).astype(int) * 255)

# %%
plot_boxes(np.any(pred_masks[pred_scores > 0.9], axis=0).astype(int) * 255, pred_boxes[pred_scores > 0.9], format='yxyx_px')
# plt.imshow(im)

# %%
dss = dl.NewData(split='train')
for idx, (im, mask, boxes, im_path, im_ID) in enumerate(dss):
    num_annotations = boxes.shape[0]
    print(f'Image {idx}:  [{im_ID}],  # annotations: {num_annotations}')
# Out:
# Image 0:  [04082023 R14 organoids_2x_RAW_ch00],  # annotations: 162
# Image 1:  [2018-08-02_Tumour organoids_MT81 Tu Organoids Px16_1],  # annotations: 422
# Image 2:  [2018-08-02_Tumour organoids_TM5807 Tu Organoids Px15 2-8-2018_2],  # annotations: 363
# Image 3:  [2018-12-12 Before injections_ TM7722 T2-1 Px16_2_ch00],  # annotations: 50
# Image 4:  [2018-12-12 Before injections_VPPK1176  Duo Px10_1_RAW_ch00],  # annotations: 51
# Image 5:  [2019-01-24 CRC R17 Px4_Image001_RAW_ch00],  # annotations: 71
# Image 6:  [2019-01-25 NSG425 T4 organoids Px3_Image003_RAW_ch00],  # annotations: 415
# Image 7:  [2019-02-16 CRC R7_CRC R7 Px6_RAW_ch00],  # annotations: 61
# Image 8:  [2019-02-26 A20 Px7_Image004_ch00],  # annotations: 289
# Image 9:  [2019-09-06 MT651 T1-1 Px5_Image001_RAW_ch00],  # annotations: 53
# Image 10:  [2019-09-06 MT651 T1-1 Px5_Image007_RAW_ch00],  # annotations: 27
# Image 11:  [2019-09-30 NSG455 T4 Px2_Series004_RAW_ch00],  # annotations: 229
# Image 12:  [2019-10-07 NSG464 T4-2 Px1_Image001_RAW_ch00],  # annotations: 167
# Image 13:  [2019-10-07 NSG464 UNK Px2_Image001_RAW_ch00],  # annotations: 66
# Image 14:  [2019-10-12 TM2118 T4 Px3_Image011_ch00],  # annotations: 44
# Image 15:  [2019-10-12 TM2118 T4 Px3_Image012_ch00],  # annotations: 24
# Image 16:  [2019-10-17 CRISPR lines under Medium Selection_TileScan 3_s25_RAW_ch00],  # annotations: 149
# Image 17:  [2019-10-17 CRISPR lines under Medium Selection_TileScan 3_s51_RAW_ch00],  # annotations: 187
# Image 18:  [2019-4-3  Before injections_R13 Px4_1_RAW_ch00],  # annotations: 100
# Image 19:  [2022-10-18_Normal organoids_Image002_ch00],  # annotations: 35
# Image 20:  [30-11-2018 TM6626 Duo Px6_Image003_RAW_ch00],  # annotations: 31
# Image 21:  [30-11-2018 TM6626 Duo Px6_Image004_RAW_ch00],  # annotations: 13
# Image 22:  [6626 Duo organoids 23-11-2018_Image002_ch00],  # annotations: 29
# Image 23:  [6626 Duo organoids 23-11-2018_Image007_ch00],  # annotations: 59
# Image 24:  [Before injections 14-08-2018_MT81 Tu Organoids Px18_3_RAW_ch00],  # annotations: 265
# Image 25:  [Before injections 30-11-2018_TM7831 Duo Px3_1_RAW_ch00],  # annotations: 58
# Image 26:  [Scan 001_8x_Multifocus Image - 1_RAW_ch00],  # annotations: 29
# Image 27:  [Scan 001_R14_8x_Multifocus Image - 1_RAW_ch00],  # annotations: 32

# %% [markdown]
# ## Tune threshold

# %%
experiment_name = 'ablation_datasets_new'

# %%
# NMS threshold
from tqdm import tqdm

nms_thres = 0.5



experiment = [
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_20_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.40', 'dataset_20', 'val', dl.OrganoID(split='test')),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_10_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.30', 'dataset_10', 'val', dl.OrganoID(split='test')),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_5_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.28', 'dataset_5', 'val', dl.OrganoID(split='test')),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_2_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.38', 'dataset_2', 'val', dl.OrganoID(split='test')),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_0_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.30', 'dataset_0', 'val', dl.OrganoID(split='test')),

    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.35', 'all_balanced_last', 'val', dl.OrganoID(split='val')),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=299-val_loss=5.31', 'all_balanced_best', 'val', dl.OrganoID(split='val')),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.98', 'public_orig_last', 'val', dl.OrganoID(split='val')),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.98', 'public_orig_best', 'val', dl.OrganoID(split='val')),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.61', 'public_balanced_last', 'val', dl.OrganoID(split='val')),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.36', 'public_balanced_best', 'val', dl.OrganoID(split='val')),
]


df = []



for backbone, ckpt_name, model_name, _, _ in experiment:
    for split, test_data in [('val', dl.OrganoID(split='val')),
                             ('val', dl.OrgaQuant(split='test')),
                             ('val', dl.OrgaSegment(split='val')),
                             ('val', dl.Tellu(split='val')),
                             ('val', dl.OrgaExtractor(split='test')),
                             ]:
        iis = np.linspace(0, len(test_data) - 1, num=4, endpoint=True).round().astype(int).tolist()
    # if ckpt_name in df_partial['ckpt_name'].unique().flatten().tolist():
    #     print('skipping')
    #     continue

        ds_name = f'{str(test_data)}_{test_data.split}'
        
        pred_base = pp.organoid_sam / 'patch_predictions' / backbone / split / ds_name / ckpt_name
        for ii in tqdm(iis):
            im, mask, boxes, im_path, im_ID = test_data[ii]
            # gt_masks = pp.convert_mask_to_binary(mask)

            # offsets, pseudo_boxes, pseudo_scores, pseudo_masks = get_pseudo_predictions(split, ds_name, im, mask, boxes, im_path, im_ID)
            # pred_boxes, pred_scores, pred_masks = pseudo_boxes, pseudo_scores, pseudo_masks  # TODO: change
            # min_shape = min(pred_boxes.shape[0], pred_masks.shape[0])
            # pred_boxes = pred_boxes[:min_shape]
            # pred_masks = pred_masks[:min_shape]
            # pred_scores = pred_scores[:min_shape]

            # pred_boxes, pred_scores, pred_masks, is_border = get_predictions(split, ds_name, pred_base, im, im_ID)
            pred_boxes, pred_scores, pred_masks, pred_patch_numbers, pred_offsets = pp.get_predictions(split, ds_name, pred_base, im, im_ID)

            print(pred_boxes.shape, boxes.shape)

            keep_masks = pred_masks.sum(axis=(1, 2)) >= 100
            pred_boxes = pred_boxes[keep_masks]
            pred_masks = pred_masks[keep_masks]
            pred_scores = pred_scores[keep_masks]
            
            # print(pred_boxes.shape, boxes.shape)

            # Filter most unrealistic ones
            # lowest_score = 0.5
            sorted_scores = np.sort(pred_scores, axis=None)
            if len(sorted_scores) < 300:
                lowest_score = 0.0
            else:
                lowest_score = np.round(sorted_scores[-300], decimals=2) 
            print(lowest_score)
            if lowest_score > 0.95:
                print('\n##### Skipping evaluation due to very high score threshold. #####\n')
                continue

            pred_boxes = pred_boxes[pred_scores >= lowest_score]
            pred_masks = pred_masks[pred_scores >= lowest_score]
            pred_scores = pred_scores[pred_scores >= lowest_score]
            
            # print(pred_boxes.shape, boxes.shape)

            iou_matrix_detection = pp.compute_iou_matrix_detection(pred_boxes, gt_boxes=boxes)
            # print('after det')
            # iou_matrix_segmentation = pp.compute_iou_matrix_segmentation(pred_masks, gt_masks)
            # print('after seg')
            
            for confidence_thres in tqdm(np.arange(0.0, 1.0, 0.01)): 
            
                # print(pred_scores.shape, pred_boxes.shape, pred_masks.shape)
            
                _pred_boxes = pred_boxes[pred_scores >= confidence_thres]
                _pred_scores = pred_scores[pred_scores >= confidence_thres]
                _iou_matrix_detection = iou_matrix_detection[pred_scores >= confidence_thres]
                # _iou_matrix_segmentation = iou_matrix_segmentation[pred_scores >= confidence_thres]
                
                # TODO: Remove boxes at patch borders

                kept_indices = pp.non_max_suppression(_pred_boxes, _pred_scores, threshold=nms_thres)
                # print('after nms')

                if len(kept_indices) != 0:
                    _iou_matrix_detection = _iou_matrix_detection[kept_indices]
                    # _iou_matrix_segmentation = _iou_matrix_segmentation[kept_indices]

                    # tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_segmentation_from_iou_matrix(
                    #     iou_matrix=_iou_matrix_segmentation, iou_threshold=0.5
                    # )
                    # df.append([experiment_name, 
                    #             f'{str(test_data)}_{test_data.split}', im_ID,
                    #             'segmentation', backbone, ckpt_name, model_name, f'{confidence_thres:.2f}',
                    #             tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                    
                    tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_detection_from_iou_matrix(
                        iou_matrix=_iou_matrix_detection, iou_threshold=0.5
                    )
                    df.append([experiment_name, 
                                f'{str(test_data)}_{test_data.split}', im_ID,
                                'detection', backbone, ckpt_name, model_name, f'{confidence_thres:.2f}',
                                tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                del _pred_boxes
                del _pred_scores
                del _iou_matrix_detection
                # del _iou_matrix_segmentation
            del pred_boxes
            del pred_masks
            del pred_scores
    df_partial = pd.DataFrame(data=df, columns=[
        'exp_name', 'testset', 'im_ID', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres',
        'tp', 'fp', 'fn', 'pq', 'precision', 'recall', 'f1_score', 'mean_iou', 'dice_coefficient'
    ])
    df_partial.to_csv(results_dir / f'thres_tuning_{experiment_name}_partial_full_val.csv')

df = pd.DataFrame(data=df, columns=[
    'exp_name', 'testset', 'im_ID', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres',
    'tp', 'fp', 'fn', 'pq', 'precision', 'recall', 'f1_score', 'mean_iou', 'dice_coefficient'
])

df.to_csv(results_dir / f'thres_tuning_{experiment_name}_full_val.csv')
df
# Out:
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2500, 4) (95, 4)
# 0.22
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 126.57it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:10<00:30, 10.25s/it]
# (2500, 4) (46, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 198.47it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:18<00:18,  9.11s/it]
# (1600, 4) (68, 4)
# 0.28
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 157.39it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:24<00:07,  7.48s/it]
# (2500, 4) (52, 4)
# 0.16
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 222.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:33<00:00,  8.28s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (400, 4) (3, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1829.79it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:01<00:04,  1.43s/it]
# (400, 4) (8, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 578.04it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:02<00:02,  1.35s/it]
# (400, 4) (11, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1163.83it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:03<00:01,  1.16s/it]
# (400, 4) (18, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 441.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.19s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1600, 4) (96, 4)
# 0.08
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 166.14it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:17,  5.89s/it]
# (1600, 4) (58, 4)
# 0.06
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 204.23it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:11<00:11,  5.65s/it]
# (8100, 4) (52, 4)
# 0.28
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 163.88it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [01:03<00:26, 26.80s/it]
# (8100, 4) (94, 4)
# 0.85
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 91.85it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [01:54<00:00, 28.74s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2000, 4) (4, 4)
# 0.04
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 571.03it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:06<00:20,  6.96s/it]
# (2000, 4) (84, 4)
# 0.26
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 144.55it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:14<00:14,  7.27s/it]
# (400, 4) (34, 4)
# 0.02
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 345.83it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:16<00:05,  5.11s/it]
# (2400, 4) (74, 4)
# 0.12
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 187.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:25<00:00,  6.30s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1500, 4) (118, 4)
# 0.92
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 106.33it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:08<00:24,  8.33s/it]
# (1500, 4) (69, 4)
# 0.37
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 125.31it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:16<00:16,  8.16s/it]
# (1500, 4) (78, 4)
# 0.49
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 125.24it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:24<00:08,  8.09s/it]
# (1500, 4) (72, 4)
# 0.18
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 122.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:32<00:00,  8.06s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2500, 4) (95, 4)
# 0.19
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 151.75it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:07<00:21,  7.11s/it]
# (2500, 4) (46, 4)
# 0.11
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 214.13it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:14<00:14,  7.35s/it]
# (1600, 4) (68, 4)
# 0.25
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 187.25it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:18<00:05,  5.88s/it]
# (2500, 4) (52, 4)
# 0.15
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 234.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:25<00:00,  6.48s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (400, 4) (3, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1875.41it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:00<00:01,  1.81it/s]
# (400, 4) (8, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 571.45it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:01<00:01,  1.29it/s]
# (400, 4) (11, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1146.07it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:02<00:00,  1.26it/s]
# (400, 4) (18, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 446.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.26it/s]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1600, 4) (96, 4)
# 0.08
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 165.63it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:04<00:14,  4.86s/it]
# (1600, 4) (58, 4)
# 0.06
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 200.10it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:09<00:09,  4.80s/it]
# (8100, 4) (52, 4)
# 0.23
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 164.37it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:59<00:25, 25.26s/it]
# (8100, 4) (94, 4)
# 0.85
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 77.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [01:45<00:00, 26.30s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2000, 4) (4, 4)
# 0.04
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 609.10it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:06<00:18,  6.32s/it]
# (2000, 4) (84, 4)
# 0.21
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 142.57it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:12<00:12,  6.43s/it]
# (400, 4) (34, 4)
# 0.02
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 345.77it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:14<00:04,  4.30s/it]
# (2400, 4) (74, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 196.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:21<00:00,  5.37s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1500, 4) (118, 4)
# 0.89
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 108.08it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:08<00:24,  8.15s/it]
# (1500, 4) (69, 4)
# 0.39
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 131.37it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:15<00:15,  7.60s/it]
# (1500, 4) (78, 4)
# 0.42
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 127.48it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:22<00:07,  7.31s/it]
# (1500, 4) (72, 4)
# 0.21
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 127.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:29<00:00,  7.40s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2500, 4) (95, 4)
# 0.22
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 148.20it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:07<00:22,  7.37s/it]
# (2500, 4) (46, 4)
# 0.12
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 203.77it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:14<00:14,  7.39s/it]
# (1600, 4) (68, 4)
# 0.26
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 176.35it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:19<00:06,  6.00s/it]
# (2500, 4) (52, 4)
# 0.16
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 239.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:26<00:00,  6.54s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (400, 4) (3, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1675.38it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:00<00:02,  1.28it/s]
# (400, 4) (8, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 511.18it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:01<00:01,  1.08it/s]
# (400, 4) (11, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1071.08it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:03<00:01,  1.19s/it]
# (400, 4) (18, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 411.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.04s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1600, 4) (96, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 167.83it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:15,  5.13s/it]
# (1600, 4) (58, 4)
# 0.07
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 209.36it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:10<00:10,  5.19s/it]
# (8100, 4) (52, 4)
# 0.23
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 165.61it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [01:02<00:26, 26.70s/it]
# (8100, 4) (94, 4)
# 0.84
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 87.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [01:54<00:00, 28.53s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2000, 4) (4, 4)
# 0.03
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 626.96it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:17,  5.95s/it]
# (2000, 4) (84, 4)
# 0.25
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 142.90it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:12<00:13,  6.59s/it]
# (400, 4) (34, 4)
# 0.02
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 356.62it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:14<00:04,  4.41s/it]
# (2400, 4) (74, 4)
# 0.12
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 194.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:22<00:00,  5.50s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1500, 4) (118, 4)
# 0.92
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 106.36it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:08<00:24,  8.15s/it]
# (1500, 4) (69, 4)
# 0.5
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 127.55it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:15<00:15,  7.72s/it]
# (1500, 4) (78, 4)
# 0.5
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 112.56it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:23<00:07,  7.69s/it]
# (1500, 4) (72, 4)
# 0.26
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 115.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:30<00:00,  7.60s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2500, 4) (95, 4)
# 0.16
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 143.07it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:06<00:20,  6.97s/it]
# (2500, 4) (46, 4)
# 0.13
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 190.42it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:14<00:14,  7.03s/it]
# (1600, 4) (68, 4)
# 0.25
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 159.89it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:18<00:05,  5.98s/it]
# (2500, 4) (52, 4)
# 0.14
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 225.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:26<00:00,  6.51s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (400, 4) (3, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1522.06it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:00<00:02,  1.07it/s]
# (400, 4) (8, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 505.75it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:01<00:01,  1.20it/s]
# (400, 4) (11, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1039.81it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:02<00:00,  1.28it/s]
# (400, 4) (18, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 393.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.22it/s]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1600, 4) (96, 4)
# 0.09
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 151.78it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:15,  5.21s/it]
# (1600, 4) (58, 4)
# 0.08
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 177.01it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:10<00:10,  5.21s/it]
# (8100, 4) (52, 4)
# 0.24
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 166.43it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [01:01<00:25, 25.98s/it]
# (8100, 4) (94, 4)
# 0.85
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 80.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [01:55<00:00, 28.84s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2000, 4) (4, 4)
# 0.03
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 660.50it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:06<00:19,  6.34s/it]
# (2000, 4) (84, 4)
# 0.23
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 143.49it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:12<00:12,  6.38s/it]
# (400, 4) (34, 4)
# 0.02
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 335.54it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:14<00:04,  4.32s/it]
# (2400, 4) (74, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 193.09it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:21<00:00,  5.43s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1500, 4) (118, 4)
# 0.91
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 107.33it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:07<00:23,  7.92s/it]
# (1500, 4) (69, 4)
# 0.44
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 126.51it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:15<00:14,  7.44s/it]
# (1500, 4) (78, 4)
# 0.51
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 122.32it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:22<00:07,  7.50s/it]
# (1500, 4) (72, 4)
# 0.3
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 121.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:29<00:00,  7.38s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2500, 4) (95, 4)
# 0.19
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 148.94it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:07<00:21,  7.14s/it]
# (2500, 4) (46, 4)
# 0.13
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 220.40it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:14<00:14,  7.15s/it]
# (1600, 4) (68, 4)
# 0.25
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 185.17it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:18<00:05,  5.92s/it]
# (2500, 4) (52, 4)
# 0.13
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 233.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:25<00:00,  6.46s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (400, 4) (3, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1443.11it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:01<00:03,  1.05s/it]
# (400, 4) (8, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 541.35it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:01<00:01,  1.06it/s]
# (400, 4) (11, 4)
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 1117.45it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:02<00:00,  1.18it/s]
# (400, 4) (18, 4)
# 0.01
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 421.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.15it/s]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1600, 4) (96, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 160.21it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:16,  5.42s/it]
# (1600, 4) (58, 4)
# 0.09
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 201.27it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:10<00:10,  5.04s/it]
# (8100, 4) (52, 4)
# 0.27
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 141.43it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [01:02<00:26, 26.75s/it]
# (8100, 4) (94, 4)
# 0.81
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 86.40it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [01:54<00:00, 28.70s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (2000, 4) (4, 4)
# 0.03
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 534.39it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:05<00:17,  5.78s/it]
# (2000, 4) (84, 4)
# 0.24
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 135.51it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:12<00:12,  6.11s/it]
# (400, 4) (34, 4)
# 0.03
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 293.19it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:14<00:04,  4.22s/it]
# (2400, 4) (74, 4)
# 0.1
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 173.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:21<00:00,  5.31s/it]
#   0%|                                                                                      | 0/4 [00:00<?, ?it/s]
# (1500, 4) (118, 4)
# 0.9
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 96.00it/s]
#  25%|███████████████████▌                                                          | 1/4 [00:08<00:24,  8.05s/it]
# (1500, 4) (69, 4)
# 0.52
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 111.44it/s]
#  50%|███████████████████████████████████████                                       | 2/4 [00:15<00:15,  7.67s/it]
# (1500, 4) (78, 4)
# 0.44
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 129.62it/s]
#  75%|██████████████████████████████████████████████████████████▌                   | 3/4 [00:22<00:07,  7.52s/it]
# (1500, 4) (72, 4)
# 0.24
# 100%|█████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 115.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:30<00:00,  7.51s/it]
#                    exp_name             testset     im_ID metric_type  \
# 0     ablation_datasets_new        OrganoID_val         0   detection
# 1     ablation_datasets_new        OrganoID_val         0   detection
# 2     ablation_datasets_new        OrganoID_val         0   detection
# 3     ablation_datasets_new        OrganoID_val         0   detection
# 4     ablation_datasets_new        OrganoID_val         0   detection
# ...                     ...                 ...       ...         ...
# 9995  ablation_datasets_new  OrgaExtractor_test  input_30   detection
# 9996  ablation_datasets_new  OrgaExtractor_test  input_30   detection
# 9997  ablation_datasets_new  OrgaExtractor_test  input_30   detection
# 9998  ablation_datasets_new  OrgaExtractor_test  input_30   detection
# 9999  ablation_datasets_new  OrgaExtractor_test  input_30   detection
#
#        backbone                                          ckpt_name  \
# 0     SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 1     SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 2     SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 3     SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 4     SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# ...         ...                                                ...
# 9995  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 9996  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 9997  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 9998  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
# 9999  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...
#
#       model_name confidence_thres  tp   fp  fn   pq  precision    recall  \
# 0     dataset_20             0.00  61  145  34  0.0   0.296117  0.642105
# 1     dataset_20             0.01  61  145  34  0.0   0.296117  0.642105
# 2     dataset_20             0.02  61  145  34  0.0   0.296117  0.642105
# 3     dataset_20             0.03  61  145  34  0.0   0.296117  0.642105
# 4     dataset_20             0.04  61  145  34  0.0   0.296117  0.642105
# ...          ...              ...  ..  ...  ..  ...        ...       ...
# 9995   dataset_0             0.95  67   43   5  0.0   0.609091  0.930556
# 9996   dataset_0             0.96  65   41   7  0.0   0.613208  0.902778
# 9997   dataset_0             0.97  62   35  10  0.0   0.639175  0.861111
# 9998   dataset_0             0.98  60   22  12  0.0   0.731707  0.833333
# 9999   dataset_0             0.99  49   12  23  0.0   0.803279  0.680556
#
#       f1_score  mean_iou  dice_coefficient
# 0     0.405316  0.753768               0.0
# 1     0.405316  0.753768               0.0
# 2     0.405316  0.753768               0.0
# 3     0.405316  0.753768               0.0
# 4     0.405316  0.753768               0.0
# ...        ...       ...               ...
# 9995  0.736264  0.891048               0.0
# 9996  0.730337  0.895903               0.0
# 9997  0.733728  0.899405               0.0
# 9998  0.779221  0.900542               0.0
# 9999  0.736842  0.910344               0.0
#
# [10000 rows x 17 columns]

# %%
# df_partial = pd.read_csv(results_dir / f'thres_tuning_{experiment_name}_partial_full_val.csv')
# df_partial = df_partial.drop(columns='Unnamed: 0')
# df_partial

# %%
# df = pd.concat([df, df_partial], axis=0, ignore_index=True)
# df

# %%
# df.to_csv(results_dir / f'thres_tuning_{experiment_name}_full_val.csv')

# %%
metrics = df.groupby(['exp_name', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres'], as_index=False).agg(
    pq_mean = pd.NamedAgg('pq', 'mean'), 
    precision_mean = pd.NamedAgg('precision', 'mean'), 
    recall_mean = pd.NamedAgg('recall', 'mean'), 
    f1_score_mean = pd.NamedAgg('f1_score', 'mean'), 
    mean_iou_mean = pd.NamedAgg('mean_iou', 'mean'), 
    dice_coefficient_mean = pd.NamedAgg('dice_coefficient', 'mean')
)
metrics
# Out:
#                   exp_name metric_type   backbone  \
# 0    ablation_datasets_new   detection  SAM_large
# 1    ablation_datasets_new   detection  SAM_large
# 2    ablation_datasets_new   detection  SAM_large
# 3    ablation_datasets_new   detection  SAM_large
# 4    ablation_datasets_new   detection  SAM_large
# ..                     ...         ...        ...
# 495  ablation_datasets_new   detection  SAM_large
# 496  ablation_datasets_new   detection  SAM_large
# 497  ablation_datasets_new   detection  SAM_large
# 498  ablation_datasets_new   detection  SAM_large
# 499  ablation_datasets_new   detection  SAM_large
#
#                                              ckpt_name model_name  \
# 0    DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_0
# 1    DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_0
# 2    DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_0
# 3    DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_0
# 4    DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_0
# ..                                                 ...        ...
# 495  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 496  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 497  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 498  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 499  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
#
#     confidence_thres  pq_mean  precision_mean  recall_mean  f1_score_mean  \
# 0               0.00      0.0        0.262190     0.928061       0.383917
# 1               0.01      0.0        0.266237     0.928061       0.390913
# 2               0.02      0.0        0.273457     0.928061       0.402089
# 3               0.03      0.0        0.278831     0.928061       0.409859
# 4               0.04      0.0        0.284629     0.928061       0.418066
# ..               ...      ...             ...          ...            ...
# 495             0.95      0.0        0.611648     0.791431       0.670567
# 496             0.96      0.0        0.632154     0.767832       0.672307
# 497             0.97      0.0        0.656910     0.724415       0.664392
# 498             0.98      0.0        0.682943     0.646362       0.635798
# 499             0.99      0.0        0.809319     0.515679       0.598281
#
#      mean_iou_mean  dice_coefficient_mean
# 0         0.819146                    0.0
# 1         0.819146                    0.0
# 2         0.819146                    0.0
# 3         0.819146                    0.0
# 4         0.819146                    0.0
# ..             ...                    ...
# 495       0.823905                    0.0
# 496       0.823578                    0.0
# 497       0.826647                    0.0
# 498       0.832778                    0.0
# 499       0.846512                    0.0
#
# [500 rows x 12 columns]

# %%
det_df = metrics.loc[metrics.metric_type == 'detection']
det_df_max = det_df.groupby(['model_name', 'ckpt_name'], as_index=False).agg(
    max_f1 = ('f1_score_mean', 'max')
    #lambda x: x[x['f1_score_mean'] == x['f1_score_mean'].max(), 'confidence_thres'].item()
)
det_df = det_df.join(det_df_max.set_index(['model_name', 'ckpt_name']), on=['model_name', 'ckpt_name'], how='left')
best_thres_df = det_df.loc[det_df['f1_score_mean'] == det_df['max_f1'], ['model_name', 'confidence_thres', 'max_f1']]
best_thres_df
# Out:
#      model_name confidence_thres    max_f1
# 96    dataset_0             0.96  0.686067
# 197  dataset_10             0.97  0.664489
# 298  dataset_20             0.98  0.669293
# 396   dataset_2             0.96  0.685669
# 496   dataset_5             0.96  0.672307

# %%
# det_df = metrics.loc[metrics.metric_type == 'detection']
# det_df_max = det_df.groupby(['model_name', 'ckpt_name'], as_index=False).agg(
#     max_f1 = ('f1_score_mean', 'max')
#     #lambda x: x[x['f1_score_mean'] == x['f1_score_mean'].max(), 'confidence_thres'].item()
# )
# det_df = det_df.join(det_df_max.set_index(['model_name', 'ckpt_name']), on=['model_name', 'ckpt_name'], how='left')
# best_thres_df = det_df.loc[det_df['f1_score_mean'] == det_df['max_f1'], ['model_name', 'confidence_thres', 'max_f1']]
# best_thres_df

# %%
best_thres_df.to_csv(results_dir / f'best_thres_df_{experiment_name}_full_val.csv')

# %%
best_thres_df = pd.read_csv(results_dir / f'best_thres_df_{experiment_name}_full_val.csv')

# %% [markdown]
# # Predict

# %% [markdown]
# boxes, scores and masks are saved in a folder called 'organoid_sam/patch_predictions/backbone/trainvaltest/dataset_name/checkpoint_name/image_ID/boxes_{i}.npy'

# %%
best_thres_df
# Out:
#    Unnamed: 0  model_name  confidence_thres    max_f1
# 0          96   dataset_0              0.96  0.686067
# 1         197  dataset_10              0.97  0.664489
# 2         298  dataset_20              0.98  0.669293
# 3         396   dataset_2              0.96  0.685669
# 4         496   dataset_5              0.96  0.672307

# %%
# NMS threshold
from tqdm import tqdm


nms_thres = 0.5

experiment = [
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_20_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.40', 'dataset_20'),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_10_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.30', 'dataset_10'),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_5_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.28', 'dataset_5'),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_2_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.38', 'dataset_2'),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_0_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.30', 'dataset_0'),

    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.35', 'all_balanced_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=299-val_loss=5.31', 'all_balanced_best'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.98', 'public_orig_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.98', 'public_orig_best'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.61', 'public_balanced_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.36', 'public_balanced_best'),
]


df = []
for split, test_data in [('test', dl.OrganoID(split='test')),
                    ('test', dl.OrganoID(split='test_Lung')),
                    ('test', dl.OrganoID(split='test_ACC')),
                    ('test', dl.OrganoID(split='test_C')),
                    ('test', dl.OrganoID(split='test_only_mouse'))]:
    for backbone, ckpt_name, model_name in experiment:
        optimal_thres = float(best_thres_df.loc[best_thres_df['model_name'] == model_name, 'confidence_thres'].item())
        print(optimal_thres)
        
        ds_name = f'{str(test_data)}_{test_data.split}'
        
        pred_base = pp.organoid_sam / 'patch_predictions' / backbone / split / ds_name / ckpt_name
        for im, mask, boxes, im_path, im_ID in tqdm(test_data):
            gt_masks = pp.convert_mask_to_binary(mask)

            pred_boxes, pred_scores, pred_masks, pred_patch_numbers, pred_offsets = pp.get_predictions(split, ds_name, pred_base, im, im_ID)
        
            # print(pred_scores.shape, pred_boxes.shape, pred_masks.shape)
        
            pred_boxes = pred_boxes[pred_scores >= optimal_thres]
            pred_masks = pred_masks[pred_scores >= optimal_thres]
            pred_patch_numbers = pred_patch_numbers[pred_scores >= optimal_thres]
            pred_offsets = pred_offsets[pred_scores >= optimal_thres]
            pred_scores = pred_scores[pred_scores >= optimal_thres]


            keep_masks = pred_masks.sum(axis=(1, 2)) >= 100
            pred_boxes = pred_boxes[keep_masks]
            pred_masks = pred_masks[keep_masks]
            pred_patch_numbers = pred_patch_numbers[keep_masks]
            pred_offsets = pred_offsets[keep_masks]
            pred_scores = pred_scores[keep_masks]
            
            
            # TODO: Remove boxes at patch borders

            kept_indices = pp.non_max_suppression(pred_boxes, pred_scores, threshold=nms_thres)
            # print('after nms')

            if len(kept_indices) != 0:
                pred_boxes = pred_boxes[kept_indices]
                pred_masks = pred_masks[kept_indices]
                pred_patch_numbers = pred_patch_numbers[kept_indices]
                pred_offsets = pred_offsets[kept_indices]
                pred_scores = pred_scores[kept_indices]

                pred_masks, pred_boxes, pred_scores = pp.stitch(pred_masks, 
                                                                pred_patch_numbers, 
                                                                pred_offsets, 
                                                                pred_boxes, 
                                                                pred_scores)

                assert pred_boxes.ndim == 2, pred_boxes.shape
                assert pred_boxes.shape[1] == 4, pred_boxes.shape
                assert pred_boxes.shape[0] == pred_masks.shape[0], pred_masks.shape
                assert pred_boxes.shape[0] == pred_scores.shape[0], pred_scores.shape

                tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_segmentation(pred_masks=pred_masks, 
                                                                                                                       gt_masks=gt_masks, 
                                                                                                                       iou_threshold=0.5)
                df.append([experiment_name, 
                           f'{str(test_data)}_{test_data.split}', im_ID, im_path,
                           'segmentation', backbone, ckpt_name, model_name, f'{optimal_thres:.2f}',
                           tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                
                tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_detection(pred_boxes=pred_boxes, 
                                                                                                                    gt_boxes=boxes, 
                                                                                                                    iou_threshold=0.5)
                df.append([experiment_name, 
                           f'{str(test_data)}_{test_data.split}', im_ID, im_path,
                           'detection', backbone, ckpt_name, model_name, f'{optimal_thres:.2f}',
                           tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                
    df_partial = pd.DataFrame(data=df, columns=[
        'exp_name', 'testset', 'im_ID', 'im_path', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres',
        'tp', 'fp', 'fn', 'pq', 'precision', 'recall', 'f1_score', 'mean_iou', 'dice_coefficient'
    ])
    df_partial.to_csv(results_dir / f'organoID_test_{experiment_name}_partial_results.csv')
    del df_partial

df = pd.DataFrame(data=df, columns=[
    'exp_name', 'testset', 'im_ID', 'im_path', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres',
    'tp', 'fp', 'fn', 'pq', 'precision', 'recall', 'f1_score', 'mean_iou', 'dice_coefficient'
])
df.to_csv(results_dir / f'organoID_test_{experiment_name}_correct_conf_thres.csv')
df
# Out:
# 0.98
# 100%|████████████████████████████████████████████████████████████████████████████| 10/10 [02:01<00:00, 12.19s/it]
# 0.97
# 100%|████████████████████████████████████████████████████████████████████████████| 10/10 [02:12<00:00, 13.24s/it]
# 0.96
# 100%|████████████████████████████████████████████████████████████████████████████| 10/10 [02:32<00:00, 15.28s/it]
# 0.96
# 100%|████████████████████████████████████████████████████████████████████████████| 10/10 [02:15<00:00, 13.52s/it]
# 0.96
# 100%|████████████████████████████████████████████████████████████████████████████| 10/10 [02:28<00:00, 14.83s/it]
# 0.98
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:24<00:00,  4.01s/it]
# 0.97
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:22<00:00,  3.76s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:23<00:00,  3.88s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:23<00:00,  3.86s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:23<00:00,  3.86s/it]
# 0.98
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:07<00:00,  1.18s/it]
# 0.97
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.09it/s]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.04it/s]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.06it/s]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:05<00:00,  1.06it/s]
# 0.98
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:10<00:00,  1.70s/it]
# 0.97
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.65s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.53s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.55s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.53s/it]
# 0.98
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:43<00:00, 10.93s/it]
# 0.97
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:47<00:00, 11.85s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:53<00:00, 13.30s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:44<00:00, 11.13s/it]
# 0.96
# 100%|██████████████████████████████████████████████████████████████████████████████| 4/4 [00:49<00:00, 12.46s/it]
#                   exp_name              testset        im_ID  \
# 0    ablation_datasets_new        OrganoID_test        PDAC1
# 1    ablation_datasets_new        OrganoID_test        PDAC1
# 2    ablation_datasets_new        OrganoID_test       PDAC10
# 3    ablation_datasets_new        OrganoID_test       PDAC10
# 4    ablation_datasets_new        OrganoID_test        PDAC2
# ..                     ...                  ...          ...
# 315  ablation_datasets_new  OrganoID_test_mouse  b_image0009
# 316  ablation_datasets_new  OrganoID_test_mouse    image0016
# 317  ablation_datasets_new  OrganoID_test_mouse    image0016
# 318  ablation_datasets_new  OrganoID_test_mouse    image0017
# 319  ablation_datasets_new  OrganoID_test_mouse    image0017
#
#                                                im_path   metric_type  \
# 0    /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 1    /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 2    /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 3    /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 4    /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# ..                                                 ...           ...
# 315  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 316  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 317  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 318  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 319  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
#
#       backbone                                          ckpt_name  model_name  \
# 0    SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20
# 1    SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20
# 2    SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20
# 3    SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20
# 4    SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20
# ..         ...                                                ...         ...
# 315  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0
# 316  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0
# 317  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0
# 318  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0
# 319  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0
#
#     confidence_thres  tp  fp   fn        pq  precision    recall  f1_score  \
# 0               0.98  36   6  144  0.269622   0.857143  0.200000  0.324324
# 1               0.98  34   8  146  0.000000   0.809524  0.188889  0.306306
# 2               0.98  48   2   31  0.642467   0.960000  0.607595  0.744186
# 3               0.98  47   3   32  0.000000   0.940000  0.594937  0.728682
# 4               0.98  41   2   13  0.721390   0.953488  0.759259  0.845361
# ..               ...  ..  ..  ...       ...        ...       ...       ...
# 315             0.96  11   3    7  0.000000   0.785714  0.611111  0.687500
# 316             0.96  30   4   52  0.434822   0.882353  0.365854  0.517241
# 317             0.96  29   5   53  0.000000   0.852941  0.353659  0.500000
# 318             0.96  14   2    4  0.727850   0.875000  0.777778  0.823529
# 319             0.96  15   1    3  0.000000   0.937500  0.833333  0.882353
#
#      mean_iou  dice_coefficient
# 0    0.831333          0.904146
# 1    0.780312          0.000000
# 2    0.863315          0.923483
# 3    0.805040          0.000000
# 4    0.853352          0.918176
# ..        ...               ...
# 315  0.792459          0.000000
# 316  0.840657          0.910251
# 317  0.739474          0.000000
# 318  0.883818          0.937162
# 319  0.823090          0.000000
#
# [320 rows x 18 columns]

# %%
sel_imgs = df[df.metric_type == 'segmentation']
sel_imgs = sel_imgs[sel_imgs.testset.isin(['OrganoID_test', 'OrganoID_test_mouse'])]
sel_imgs = sel_imgs[sel_imgs.model_name == 'dataset_5']
sel_imgs
# Out:
#                   exp_name              testset        im_ID  \
# 40   ablation_datasets_new        OrganoID_test        PDAC1
# 42   ablation_datasets_new        OrganoID_test       PDAC10
# 44   ablation_datasets_new        OrganoID_test        PDAC2
# 46   ablation_datasets_new        OrganoID_test        PDAC3
# 48   ablation_datasets_new        OrganoID_test        PDAC4
# 50   ablation_datasets_new        OrganoID_test        PDAC5
# 52   ablation_datasets_new        OrganoID_test        PDAC6
# 54   ablation_datasets_new        OrganoID_test        PDAC7
# 56   ablation_datasets_new        OrganoID_test        PDAC8
# 58   ablation_datasets_new        OrganoID_test        PDAC9
# 296  ablation_datasets_new  OrganoID_test_mouse  b_image0007
# 298  ablation_datasets_new  OrganoID_test_mouse  b_image0009
# 300  ablation_datasets_new  OrganoID_test_mouse    image0016
# 302  ablation_datasets_new  OrganoID_test_mouse    image0017
#
#                                                im_path   metric_type  \
# 40   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 42   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 44   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 46   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 48   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 50   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 52   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 54   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 56   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 58   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 296  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 298  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 300  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 302  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
#
#       backbone                                          ckpt_name model_name  \
# 40   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 42   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 44   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 46   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 48   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 50   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 52   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 54   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 56   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 58   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 296  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 298  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 300  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 302  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
#
#     confidence_thres  tp  fp   fn        pq  precision    recall  f1_score  \
# 40              0.96  46  18  134  0.301630   0.718750  0.255556  0.377049
# 42              0.96  57   5   22  0.707146   0.919355  0.721519  0.808511
# 44              0.96  48   7    6  0.755989   0.872727  0.888889  0.880734
# 46              0.96  24  16    2  0.553800   0.600000  0.923077  0.727273
# 48              0.96  18   4    4  0.706857   0.818182  0.818182  0.818182
# 50              0.96  23   8    4  0.625286   0.741935  0.851852  0.793103
# 52              0.96  19   1   14  0.629066   0.950000  0.575758  0.716981
# 54              0.96  20   2   18  0.539969   0.909091  0.526316  0.666667
# 56              0.96  36  13   15  0.603979   0.734694  0.705882  0.720000
# 58              0.96  61   7   52  0.582817   0.897059  0.539823  0.674033
# 296             0.96   8   1    4  0.664195   0.888889  0.666667  0.761905
# 298             0.96  11   2    7  0.613831   0.846154  0.611111  0.709677
# 300             0.96  35   3   47  0.488418   0.921053  0.426829  0.583333
# 302             0.96  16   2    2  0.782810   0.888889  0.888889  0.888889
#
#      mean_iou  dice_coefficient
# 40   0.799976          0.884280
# 42   0.874628          0.931479
# 44   0.858363          0.921923
# 46   0.761474          0.859415
# 48   0.863936          0.924699
# 50   0.788404          0.877143
# 52   0.877382          0.933666
# 54   0.809954          0.889935
# 56   0.838860          0.908251
# 58   0.864672          0.924776
# 296  0.871757          0.929447
# 298  0.864944          0.924924
# 300  0.837289          0.908083
# 302  0.880661          0.935404

# %%
sel_imgs.groupby(['testset']).agg(
    median_pq = ('pq', 'median')
)
# Out:
#                      median_pq
# testset
# OrganoID_test         0.614633
# OrganoID_test_mouse   0.639013

# %%
print(f'organoID_test_{experiment_name}_correct_conf_thres')
# Out:
# organoID_test_ablation_datasets_new_correct_conf_thres

# %%
# df = pd.read_csv(results_dir / f'organoID_test_{experiment_name}_correct_conf_thres.csv')

# %%
metrics = df.groupby(['exp_name', 'testset', 'metric_type', 'backbone', 'ckpt_name', 'model_name', #'confidence_thres'
                      ], as_index=False).agg(
    pq_mean = pd.NamedAgg('pq', 'mean'), 
    precision_mean = pd.NamedAgg('precision', 'mean'), 
    recall_mean = pd.NamedAgg('recall', 'mean'), 
    f1_score_mean = pd.NamedAgg('f1_score', 'mean'), 
    mean_iou_mean = pd.NamedAgg('mean_iou', 'mean'), 
    dice_coefficient_mean = pd.NamedAgg('dice_coefficient', 'mean')
)
metrics.head(40)
# Out:
#                  exp_name             testset   metric_type   backbone  \
# 0   ablation_datasets_new       OrganoID_test     detection  SAM_large
# 1   ablation_datasets_new       OrganoID_test     detection  SAM_large
# 2   ablation_datasets_new       OrganoID_test     detection  SAM_large
# 3   ablation_datasets_new       OrganoID_test     detection  SAM_large
# 4   ablation_datasets_new       OrganoID_test     detection  SAM_large
# 5   ablation_datasets_new       OrganoID_test  segmentation  SAM_large
# 6   ablation_datasets_new       OrganoID_test  segmentation  SAM_large
# 7   ablation_datasets_new       OrganoID_test  segmentation  SAM_large
# 8   ablation_datasets_new       OrganoID_test  segmentation  SAM_large
# 9   ablation_datasets_new       OrganoID_test  segmentation  SAM_large
# 10  ablation_datasets_new   OrganoID_test_ACC     detection  SAM_large
# 11  ablation_datasets_new   OrganoID_test_ACC     detection  SAM_large
# 12  ablation_datasets_new   OrganoID_test_ACC     detection  SAM_large
# 13  ablation_datasets_new   OrganoID_test_ACC     detection  SAM_large
# 14  ablation_datasets_new   OrganoID_test_ACC     detection  SAM_large
# 15  ablation_datasets_new   OrganoID_test_ACC  segmentation  SAM_large
# 16  ablation_datasets_new   OrganoID_test_ACC  segmentation  SAM_large
# 17  ablation_datasets_new   OrganoID_test_ACC  segmentation  SAM_large
# 18  ablation_datasets_new   OrganoID_test_ACC  segmentation  SAM_large
# 19  ablation_datasets_new   OrganoID_test_ACC  segmentation  SAM_large
# 20  ablation_datasets_new     OrganoID_test_C     detection  SAM_large
# 21  ablation_datasets_new     OrganoID_test_C     detection  SAM_large
# 22  ablation_datasets_new     OrganoID_test_C     detection  SAM_large
# 23  ablation_datasets_new     OrganoID_test_C     detection  SAM_large
# 24  ablation_datasets_new     OrganoID_test_C     detection  SAM_large
# 25  ablation_datasets_new     OrganoID_test_C  segmentation  SAM_large
# 26  ablation_datasets_new     OrganoID_test_C  segmentation  SAM_large
# 27  ablation_datasets_new     OrganoID_test_C  segmentation  SAM_large
# 28  ablation_datasets_new     OrganoID_test_C  segmentation  SAM_large
# 29  ablation_datasets_new     OrganoID_test_C  segmentation  SAM_large
# 30  ablation_datasets_new  OrganoID_test_Lung     detection  SAM_large
# 31  ablation_datasets_new  OrganoID_test_Lung     detection  SAM_large
# 32  ablation_datasets_new  OrganoID_test_Lung     detection  SAM_large
# 33  ablation_datasets_new  OrganoID_test_Lung     detection  SAM_large
# 34  ablation_datasets_new  OrganoID_test_Lung     detection  SAM_large
# 35  ablation_datasets_new  OrganoID_test_Lung  segmentation  SAM_large
# 36  ablation_datasets_new  OrganoID_test_Lung  segmentation  SAM_large
# 37  ablation_datasets_new  OrganoID_test_Lung  segmentation  SAM_large
# 38  ablation_datasets_new  OrganoID_test_Lung  segmentation  SAM_large
# 39  ablation_datasets_new  OrganoID_test_Lung  segmentation  SAM_large
#
#                                             ckpt_name  model_name   pq_mean  \
# 0   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.000000
# 1   DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.000000
# 2   DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.000000
# 3   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.000000
# 4   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.000000
# 5   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.589984
# 6   DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.579946
# 7   DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.566612
# 8   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.598743
# 9   DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.600654
# 10  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.000000
# 11  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.000000
# 12  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.000000
# 13  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.000000
# 14  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.000000
# 15  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.614581
# 16  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.589522
# 17  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.542839
# 18  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.636255
# 19  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.641483
# 20  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.000000
# 21  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.000000
# 22  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.000000
# 23  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.000000
# 24  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.000000
# 25  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.721033
# 26  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.717435
# 27  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.737078
# 28  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.709771
# 29  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.727169
# 30  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.000000
# 31  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.000000
# 32  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.000000
# 33  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.000000
# 34  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.000000
# 35  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_0  0.834300
# 36  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_10  0.825609
# 37  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_20  0.779445
# 38  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_2  0.829018
# 39  DetectionHead_SAM_large_OrganoID_train_MultiOr...   dataset_5  0.821686
#
#     precision_mean  recall_mean  f1_score_mean  mean_iou_mean  \
# 0         0.806900     0.628578       0.688826       0.784993
# 1         0.806420     0.620173       0.676265       0.787538
# 2         0.852921     0.560541       0.650642       0.793474
# 3         0.827254     0.662400       0.706992       0.784488
# 4         0.795604     0.666802       0.703407       0.790176
# 5         0.830233     0.644437       0.706170       0.833608
# 6         0.834596     0.641724       0.698497       0.828624
# 7         0.883888     0.588404       0.678733       0.835990
# 8         0.839913     0.675935       0.718444       0.831036
# 9         0.816179     0.680685       0.718253       0.833765
# 10        0.830357     0.617595       0.646330       0.730194
# 11        0.845238     0.556308       0.605060       0.726959
# 12        0.875000     0.529256       0.587633       0.735353
# 13        0.856481     0.633572       0.680690       0.738592
# 14        0.850033     0.645477       0.675010       0.725568
# 15        0.892857     0.660805       0.695069       0.881399
# 16        0.916667     0.611863       0.667560       0.874108
# 17        0.916667     0.547775       0.613274       0.879919
# 18        0.898148     0.670609       0.719905       0.876006
# 19        0.905589     0.701032       0.730566       0.876758
# 20        0.811748     0.793269       0.790661       0.801735
# 21        0.813095     0.797276       0.797228       0.789337
# 22        0.917388     0.763301       0.827056       0.802993
# 23        0.769444     0.797276       0.777132       0.806863
# 24        0.794682     0.814103       0.794287       0.801711
# 25        0.852346     0.828686       0.827818       0.869769
# 26        0.851984     0.832692       0.833808       0.860163
# 27        0.932540     0.773718       0.839402       0.879306
# 28        0.805655     0.832692       0.812653       0.873140
# 29        0.845323     0.859936       0.841951       0.862487
# 30        0.939922     0.897462       0.916226       0.850884
# 31        0.926176     0.864776       0.892042       0.857349
# 32        0.939715     0.810889       0.869961       0.856575
# 33        0.948666     0.878661       0.911225       0.855703
# 34        0.904431     0.899413       0.900668       0.856427
# 35        0.942952     0.900150       0.919075       0.907661
# 36        0.945826     0.884235       0.911576       0.905427
# 37        0.927810     0.800472       0.858849       0.906758
# 38        0.951590     0.881349       0.914026       0.906662
# 39        0.911985     0.906863       0.908164       0.904599
#
#     dice_coefficient_mean
# 0                0.000000
# 1                0.000000
# 2                0.000000
# 3                0.000000
# 4                0.000000
# 5                0.905570
# 6                0.901904
# 7                0.906761
# 8                0.903763
# 9                0.905557
# 10               0.000000
# 11               0.000000
# 12               0.000000
# 13               0.000000
# 14               0.000000
# 15               0.934703
# 16               0.930159
# 17               0.933459
# 18               0.931282
# 19               0.932153
# 20               0.000000
# 21               0.000000
# 22               0.000000
# 23               0.000000
# 24               0.000000
# 25               0.926860
# 26               0.920474
# 27               0.932626
# 28               0.928763
# 29               0.921659
# 30               0.000000
# 31               0.000000
# 32               0.000000
# 33               0.000000
# 34               0.000000
# 35               0.949263
# 36               0.947537
# 37               0.948522
# 38               0.948475
# 39               0.947290

# %%
metrics.to_csv(results_dir / f'organoID_test_{experiment_name}_correct_conf_thres_aggregated.csv')
# metrics.head(40)

# %%
print(f'organoID_test_{experiment_name}_correct_conf_thres_aggregated')
# Out:
# organoID_test_ablation_datasets_new_correct_conf_thres_aggregated

# %%
pq_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='pq_mean'
).loc[['dataset_0', 'dataset_2', 'dataset_5', 'dataset_10', 'dataset_20'], :]
# pq_metrics.to_csv(results_dir / f'{experiment_name}_PQ.csv')
pq_metrics #.loc[['MicroSAM_base_best', 'SAM2_large_best', 'SAM_large_best', 'SAM_base_best'], :]
# Out:
# testset     OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# dataset_0        0.589984           0.614581         0.721033
# dataset_2        0.598743           0.636255         0.709771
# dataset_5        0.600654           0.641483         0.727169
# dataset_10       0.579946           0.589522         0.717435
# dataset_20       0.566612           0.542839         0.737078
#
# testset     OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# dataset_0             0.834300             0.605430
# dataset_2             0.829018             0.600368
# dataset_5             0.821686             0.637314
# dataset_10            0.825609             0.585154
# dataset_20            0.779445             0.577615

# %%
import matplotlib

plt.style.use('ggplot')

base_datadir = Path('/ictstr01/groups/shared/users/lion.gleiter/organoid_sam/original_data/')
results_dir = Path('/ictstr01/groups/shared/users/lion.gleiter/organoid_sam/results')

col_width_inch = 3.25
twocol_width_inch = 6.875

dpi=250
matplotlib.rcParams['figure.dpi'] = dpi
matplotlib.rcParams['font.size'] = 4

def plot_metric(table, metric='pq_mean', ylabel='Panoptic Quality'):
    table = table[table.metric_type=='segmentation']
    table = table[table.model_name.isin(['dataset_0', 'dataset_2', 'dataset_5', 'dataset_10', 'dataset_20'])]

    table = table.replace({
        'dataset_0': '0 % SAMOS data', 
        'dataset_2': '2 % SAMOS data', 
        'dataset_5': '5 % SAMOS data', 
        'dataset_10': '10 % SAMOS data', 
        'dataset_20': '20 % SAMOS data',
        'OrganoID_test': 'PDAC', 
        'OrganoID_test_Lung': 'Lung', 
        'OrganoID_test_ACC': 'ACC', 
        'OrganoID_test_C': 'Colon', 
        'OrganoID_test_mouse': 'Mouse'
    })

    table = table.pivot(
        index='model_name', columns='testset', values=metric
    ).loc[['0 % SAMOS data', '2 % SAMOS data', '5 % SAMOS data', '10 % SAMOS data', '20 % SAMOS data'], :]

    
    # Define organoid types and models
    organoid_types = ['PDAC', 'Lung', 'ACC', 'Colon', 'Mouse']
    models = ['0 % SAMOS data', '2 % SAMOS data', '5 % SAMOS data', '10 % SAMOS data', '20 % SAMOS data']

    # Extract PQ values for each model and organoid type
    # pq_values_by_type = {organoid: table[models, organoid].values 
    #                      for organoid in organoid_types}

    # Bar width and x-axis positions
    bar_width = 0.18
    x = np.arange(len(organoid_types))

    # Define color map
    color_map = {
        '0 % SAMOS data': (203/255, 233/255, 157/255),      # Light Green
        '2 % SAMOS data': (135/255, 207/255, 164/255),      # Soft Teal
        '5 % SAMOS data': (70/255, 158/255, 180/255),  # Bright Teal
        '10 % SAMOS data': (78/255, 98/255, 171/255),  # Deep Purple
        '20 % SAMOS data': (80/255, 80/255, 80/255),  # Dark Grey
    }

    # Set global font sizes
    plt.rcParams['font.size'] = 12         
    plt.rcParams['axes.labelsize'] = 14     
    plt.rcParams['xtick.labelsize'] = 12    
    plt.rcParams['ytick.labelsize'] = 12    
    plt.rcParams['legend.fontsize'] = 11    
    plt.rcParams['legend.title_fontsize'] = 13  

    # Plotting
    plt.figure(figsize=(8, 5))

    # Plot each model's bars with an offset for each organoid type
    for i, model in enumerate(models):
        # pq_values = [pq_values_by_type[organoid][i] for organoid in organoid_types]
        pq_values = table.loc[model, organoid_types].values
        plt.bar(x + i * bar_width, pq_values, bar_width, label=model, color=color_map[model])

    # Labeling and legend
    plt.xlabel('Organoid type', fontsize=14)
    plt.ylabel(ylabel, fontsize=14)
    plt.xticks(x + bar_width * 2.0, organoid_types)  # Adjust x-ticks to align with bars
    plt.legend(title='Training set', loc='lower right')
    plt.tight_layout()

    # Save the plot as PDF
    (results_dir / 'plots').mkdir(exist_ok=True)
    plt.savefig(results_dir / 'plots' / f'ablation_{experiment_name}_{metric}.pdf', format='pdf', dpi=300)
    plt.savefig(results_dir / 'plots' / f'ablation_{experiment_name}_{metric}.png', format='png', dpi=300)

    # Display the plot
    plt.show()

# %%
# metrics

# %%
plot_metric(table=metrics, metric='pq_mean', ylabel='Panoptic Quality')

# %%
plot_metric(table=metrics, metric='f1_score_mean')

# %%
plot_metric(table=metrics, metric='mean_iou_mean')

# %%
pq_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='pq_mean'
).loc[['CellSAM_best', 'MedSAM_best', 'MicroSAM_base_best', 'MicroSAM_large_best', 'MicroSAM_huge_best', 'SAM_base_best', 'SAM_large_best', 'SAM2_large_best'], :]
pq_metrics.to_csv(results_dir / f'{experiment_name}_PQ.csv')
pq_metrics #.loc[['MicroSAM_base_best', 'SAM2_large_best', 'SAM_large_best', 'SAM_base_best'], :]
# Out:
# testset              OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# CellSAM_best              0.197018           0.214435         0.250819
# MedSAM_best               0.222629           0.255354         0.257479
# MicroSAM_base_best        0.532192           0.566320         0.536982
# MicroSAM_large_best       0.474462           0.488720         0.588228
# MicroSAM_huge_best        0.471023           0.527107         0.507411
# SAM_base_best             0.486851           0.593540         0.436241
# SAM_large_best            0.500034           0.618009         0.555269
# SAM2_large_best           0.560355           0.557548         0.604707
#
# testset              OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# CellSAM_best                   0.445552             0.015023
# MedSAM_best                    0.410882             0.121487
# MicroSAM_base_best             0.759669             0.371441
# MicroSAM_large_best            0.692021             0.408004
# MicroSAM_huge_best             0.692646             0.379354
# SAM_base_best                  0.736352             0.583274
# SAM_large_best                 0.791746             0.542728
# SAM2_large_best                0.740009             0.457462

# %%
pq_metrics_ = pd.read_csv(results_dir / f'ablation_dataset_PQ.csv')
pq_metrics #.loc[['MicroSAM_base_best', 'SAM2_large_best', 'SAM_large_best', 'SAM_base_best'], :]

# %%
f1_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='f1_score_mean'
).loc[['MicroSAM_base_best', 'SAM_base_best', 'SAM_large_best', 'SAM2_large_best'], :]
f1_metrics.to_csv(results_dir / 'ablation_SAM_variants_F1_subset.csv')
f1_metrics
# Out:
# testset             OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# MicroSAM_base_best       0.665814           0.687263         0.655538
# SAM_base_best            0.597220           0.685502         0.502781
# SAM_large_best           0.591267           0.725582         0.595997
# SAM2_large_best          0.682654           0.659888         0.715416
#
# testset             OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# MicroSAM_base_best            0.879190             0.512109
# SAM_base_best                 0.833945             0.706133
# SAM_large_best                0.861216             0.665041
# SAM2_large_best               0.829858             0.585937

# %%
f1_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='f1_score_mean'
).loc[['MicroSAM_base_best', 'SAM_base_best', 'SAM_large_best', 'SAM2_large_best'], :]
f1_metrics.to_csv(results_dir / 'ablation_SAM_variants_F1_subset.csv')
f1_metrics
# Out:
# testset             OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# MicroSAM_base_best       0.668858           0.687263         0.664234
# SAM_base_best            0.610868           0.690276         0.522232
# SAM_large_best           0.612436           0.726062         0.649338
# SAM2_large_best          0.698366           0.659888         0.728559
#
# testset             OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# MicroSAM_base_best            0.876722             0.512109
# SAM_base_best                 0.837448             0.706133
# SAM_large_best                0.870567             0.665041
# SAM2_large_best               0.844337             0.585937

# %%
mean_iou_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='mean_iou_mean'
).loc[['MicroSAM_base_best', 'SAM_base_best', 'SAM_large_best', 'SAM2_large_best'], :]
mean_iou_metrics.to_csv(results_dir / 'ablation_SAM_variants_Mean_IoU_subset.csv')
mean_iou_metrics
# Out:
# testset             OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# MicroSAM_base_best       0.789321           0.817503         0.808309
# SAM_base_best            0.788577           0.857958         0.831899
# SAM_large_best           0.809683           0.849978         0.853562
# SAM2_large_best          0.798173           0.844022         0.829588
#
# testset             OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# MicroSAM_base_best            0.863387             0.713780
# SAM_base_best                 0.877994             0.825246
# SAM_large_best                0.909865             0.814600
# SAM2_large_best               0.875867             0.780981

# %%
mean_iou_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='mean_iou_mean'
).loc[['MicroSAM_base_best', 'SAM_base_best', 'SAM_large_best', 'SAM2_large_best'], :]
mean_iou_metrics.to_csv(results_dir / 'ablation_SAM_variants_Mean_IoU_subset.csv')
mean_iou_metrics
# Out:
# testset             OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# MicroSAM_base_best       0.792958           0.817503         0.808309
# SAM_base_best            0.789020           0.857958         0.831899
# SAM_large_best           0.812270           0.851698         0.853562
# SAM2_large_best          0.799921           0.844022         0.829588
#
# testset             OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# MicroSAM_base_best            0.865053             0.713780
# SAM_base_best                 0.877994             0.825246
# SAM_large_best                0.909587             0.814600
# SAM2_large_best               0.875867             0.780981

# %% [markdown]
# ### Plots

# %%
metrics_orgasegment_ours = pd.read_csv(results_dir / f'organoID_test_orgasegment_comparison_correct_conf_thres_aggregated.csv')
metrics_orgasegment_ours.head(40)
# Out:
#     Unnamed: 0                exp_name            testset   metric_type  \
# 0            0  orgasegment_comparison      OrganoID_test     detection
# 1            1  orgasegment_comparison      OrganoID_test     detection
# 2            2  orgasegment_comparison      OrganoID_test     detection
# 3            3  orgasegment_comparison      OrganoID_test     detection
# 4            4  orgasegment_comparison      OrganoID_test     detection
# 5            5  orgasegment_comparison      OrganoID_test     detection
# 6            6  orgasegment_comparison      OrganoID_test     detection
# 7            7  orgasegment_comparison      OrganoID_test     detection
# 8            8  orgasegment_comparison      OrganoID_test  segmentation
# 9            9  orgasegment_comparison      OrganoID_test  segmentation
# 10          10  orgasegment_comparison      OrganoID_test  segmentation
# 11          11  orgasegment_comparison      OrganoID_test  segmentation
# 12          12  orgasegment_comparison      OrganoID_test  segmentation
# 13          13  orgasegment_comparison      OrganoID_test  segmentation
# 14          14  orgasegment_comparison      OrganoID_test  segmentation
# 15          15  orgasegment_comparison      OrganoID_test  segmentation
# 16          16  orgasegment_comparison  OrganoID_test_ACC     detection
# 17          17  orgasegment_comparison  OrganoID_test_ACC     detection
# 18          18  orgasegment_comparison  OrganoID_test_ACC     detection
# 19          19  orgasegment_comparison  OrganoID_test_ACC     detection
# 20          20  orgasegment_comparison  OrganoID_test_ACC     detection
# 21          21  orgasegment_comparison  OrganoID_test_ACC     detection
# 22          22  orgasegment_comparison  OrganoID_test_ACC     detection
# 23          23  orgasegment_comparison  OrganoID_test_ACC     detection
# 24          24  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 25          25  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 26          26  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 27          27  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 28          28  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 29          29  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 30          30  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 31          31  orgasegment_comparison  OrganoID_test_ACC  segmentation
# 32          32  orgasegment_comparison    OrganoID_test_C     detection
# 33          33  orgasegment_comparison    OrganoID_test_C     detection
# 34          34  orgasegment_comparison    OrganoID_test_C     detection
# 35          35  orgasegment_comparison    OrganoID_test_C     detection
# 36          36  orgasegment_comparison    OrganoID_test_C     detection
# 37          37  orgasegment_comparison    OrganoID_test_C     detection
# 38          38  orgasegment_comparison    OrganoID_test_C     detection
# 39          39  orgasegment_comparison    OrganoID_test_C     detection
#
#      backbone                                          ckpt_name  \
# 0   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 1   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 2   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 3   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 4   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 5   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 6   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 7   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 8   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 9   SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 10  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 11  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 12  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 13  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 14  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 15  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 16  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 17  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 18  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 19  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 20  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 21  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 22  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 23  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 24  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 25  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 26  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 27  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 28  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 29  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 30  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 31  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 32  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 33  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 34  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 35  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 36  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 37  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 38  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
# 39  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
#
#              model_name   pq_mean  precision_mean  recall_mean  f1_score_mean  \
# 0   no_pretraining_best  0.000000        0.565898     0.470829       0.486638
# 1   no_pretraining_last  0.000000        0.592947     0.488204       0.511908
# 2          NeurIPS_best  0.000000        0.697032     0.468219       0.542019
# 3          NeurIPS_last  0.000000        0.713663     0.442126       0.528173
# 4               OI_best  0.000000        0.717021     0.491438       0.547886
# 5               OI_last  0.000000        0.689223     0.474995       0.529849
# 6   OI_and_NeurIPS_best  0.000000        0.693883     0.573620       0.599545
# 7   OI_and_NeurIPS_last  0.000000        0.717243     0.511939       0.571156
# 8   no_pretraining_best  0.467015        0.663297     0.559374       0.572911
# 9   no_pretraining_last  0.471971        0.670629     0.552170       0.578963
# 10         NeurIPS_best  0.503137        0.772349     0.527836       0.605417
# 11         NeurIPS_last  0.478879        0.778625     0.481212       0.575721
# 12              OI_best  0.489786        0.773622     0.530653       0.590980
# 13              OI_last  0.481491        0.756364     0.522854       0.582083
# 14  OI_and_NeurIPS_best  0.527441        0.743388     0.610545       0.638954
# 15  OI_and_NeurIPS_last  0.525995        0.799722     0.576813       0.640066
# 16  no_pretraining_best  0.000000        0.727778     0.680413       0.665150
# 17  no_pretraining_last  0.000000        0.721950     0.652090       0.651163
# 18         NeurIPS_best  0.000000        0.781052     0.598791       0.641261
# 19         NeurIPS_last  0.000000        0.847527     0.614223       0.666394
# 20              OI_best  0.000000        0.744802     0.658912       0.671400
# 21              OI_last  0.000000        0.846289     0.631964       0.661639
# 22  OI_and_NeurIPS_best  0.000000        0.757247     0.733634       0.723130
# 23  OI_and_NeurIPS_last  0.000000        0.859975     0.539216       0.613796
# 24  no_pretraining_best  0.596138        0.755556     0.698491       0.684826
# 25  no_pretraining_last  0.584889        0.750272     0.663165       0.666958
# 26         NeurIPS_best  0.581077        0.787996     0.611137       0.653960
# 27         NeurIPS_last  0.582323        0.841829     0.612953       0.664227
# 28              OI_best  0.583585        0.730913     0.652739       0.662853
# 29              OI_last  0.563577        0.814950     0.620889       0.645287
# 30  OI_and_NeurIPS_best  0.645208        0.768358     0.739807       0.731067
# 31  OI_and_NeurIPS_last  0.549942        0.859975     0.539216       0.613796
# 32  no_pretraining_best  0.000000        0.656006     0.668910       0.653721
# 33  no_pretraining_last  0.000000        0.672490     0.656090       0.659649
# 34         NeurIPS_best  0.000000        0.698575     0.618590       0.650678
# 35         NeurIPS_last  0.000000        0.712793     0.592949       0.642593
# 36              OI_best  0.000000        0.641084     0.604167       0.615392
# 37              OI_last  0.000000        0.735272     0.645994       0.681775
# 38  OI_and_NeurIPS_best  0.000000        0.762416     0.662500       0.698897
# 39  OI_and_NeurIPS_last  0.000000        0.807071     0.596955       0.680028
#
#     mean_iou_mean  dice_coefficient_mean
# 0        0.715293               0.000000
# 1        0.712827               0.000000
# 2        0.735094               0.000000
# 3        0.729683               0.000000
# 4        0.742746               0.000000
# 5        0.746580               0.000000
# 6        0.749804               0.000000
# 7        0.763583               0.000000
# 8        0.814171               0.892117
# 9        0.818058               0.894790
# 10       0.830750               0.903184
# 11       0.832228               0.904554
# 12       0.831059               0.903585
# 13       0.828381               0.901899
# 14       0.824327               0.899239
# 15       0.823528               0.898438
# 16       0.757510               0.000000
# 17       0.778731               0.000000
# 18       0.778318               0.000000
# 19       0.780937               0.000000
# 20       0.785011               0.000000
# 21       0.777853               0.000000
# 22       0.786535               0.000000
# 23       0.804485               0.000000
# 24       0.860540               0.921999
# 25       0.868466               0.926706
# 26       0.877025               0.931795
# 27       0.865220               0.924544
# 28       0.873963               0.930060
# 29       0.866217               0.925493
# 30       0.877706               0.932547
# 31       0.893712               0.941563
# 32       0.728609               0.000000
# 33       0.721562               0.000000
# 34       0.722027               0.000000
# 35       0.730640               0.000000
# 36       0.757287               0.000000
# 37       0.759360               0.000000
# 38       0.736476               0.000000
# 39       0.736563               0.000000

# %%
metrics_orgasegment_ours = metrics_orgasegment_ours[metrics_orgasegment_ours.metric_type=='segmentation']

# %%
metrics_orgasegment_ours = metrics_orgasegment_ours[metrics_orgasegment_ours.testset == 'OrganoID_test_Lung']

# %%
metrics_orgasegment_ours[metrics_orgasegment_ours.model_name == 'OI_and_NeurIPS_best']
# Out:
#     Unnamed: 0                exp_name             testset   metric_type  \
# 62          62  orgasegment_comparison  OrganoID_test_Lung  segmentation
#
#      backbone                                          ckpt_name  \
# 62  SAM_large  DetectionHead_SAM_large_OrgaSegment_train_fine...
#
#              model_name   pq_mean  precision_mean  recall_mean  f1_score_mean  \
# 62  OI_and_NeurIPS_best  0.737434        0.852472     0.797837       0.823282
#
#     mean_iou_mean  dice_coefficient_mean
# 62       0.894376               0.941056

# %%
# NMS threshold
from tqdm import tqdm

experiment_name = 'ablation_datasets_orgasegment_testdata'

nms_thres = 0.5

experiment = [
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_20_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.40', 'dataset_20'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_10_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.30', 'dataset_10'),
    ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_5_pre_OI_NeurIPS_True_32_200-best_epoch=449-val_loss=5.28', 'dataset_5'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_2_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.38', 'dataset_2'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_ablation_dataset_0_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.30', 'dataset_0'),

    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.35', 'all_balanced_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_NewData_train_finetune_all_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=299-val_loss=5.31', 'all_balanced_best'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.98', 'public_orig_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_orig_pre_OI_NeurIPS_True_32_200-best_epoch=499-val_loss=5.98', 'public_orig_best'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-last_epoch=499-val_loss=5.61', 'public_balanced_last'),
    # ('SAM_large', 'DetectionHead_SAM_large_OrganoID_train_MultiOrg_train_macros_MultiOrg_train_normal_OrgaExtractor_train_OrgaQuant_train_OrgaSegment_train_Tellu_train_finetune_public_balanced_pre_OI_NeurIPS_True_32_200-best_epoch=399-val_loss=5.36', 'public_balanced_best'),
]


df_multiorg = []
for split, test_data in [('test', dl.OrgaSegment(split='test')),]:
    for backbone, ckpt_name, model_name in experiment:
        optimal_thres = 0.85 # float(best_thres_df.loc[best_thres_df['model_name'] == model_name, 'confidence_thres'].item())
        print(optimal_thres)
        
        ds_name = f'{str(test_data)}_{test_data.split}'
        
        pred_base = pp.organoid_sam / 'patch_predictions' / backbone / split / ds_name / ckpt_name
        for im, mask, boxes, im_path, im_ID in tqdm(test_data):
            gt_masks = pp.convert_mask_to_binary(mask)

            pred_boxes, pred_scores, pred_masks, pred_patch_numbers, pred_offsets = pp.get_predictions(split, ds_name, pred_base, im, im_ID) #, cthres=optimal_thres)
        
            # print(pred_scores.shape, pred_boxes.shape, pred_masks.shape)
        
            pred_boxes = pred_boxes[pred_scores >= optimal_thres]
            pred_masks = pred_masks[pred_scores >= optimal_thres]
            pred_patch_numbers = pred_patch_numbers[pred_scores >= optimal_thres]
            pred_offsets = pred_offsets[pred_scores >= optimal_thres]
            pred_scores = pred_scores[pred_scores >= optimal_thres]


            keep_masks = pred_masks.sum(axis=(1, 2)) >= 100
            pred_boxes = pred_boxes[keep_masks]
            pred_masks = pred_masks[keep_masks]
            pred_patch_numbers = pred_patch_numbers[keep_masks]
            pred_offsets = pred_offsets[keep_masks]
            pred_scores = pred_scores[keep_masks]
            
            
            # TODO: Remove boxes at patch borders

            kept_indices = pp.non_max_suppression(pred_boxes, pred_scores, threshold=nms_thres)
            # print('after nms')

            if len(kept_indices) != 0:
                pred_boxes = pred_boxes[kept_indices]
                pred_masks = pred_masks[kept_indices]
                pred_patch_numbers = pred_patch_numbers[kept_indices]
                pred_offsets = pred_offsets[kept_indices]
                pred_scores = pred_scores[kept_indices]

                pred_masks, pred_boxes, pred_scores = pp.stitch(pred_masks, 
                                                                pred_patch_numbers, 
                                                                pred_offsets, 
                                                                pred_boxes, 
                                                                pred_scores)

                assert pred_boxes.ndim == 2, pred_boxes.shape
                assert pred_boxes.shape[1] == 4, pred_boxes.shape
                assert pred_boxes.shape[0] == pred_masks.shape[0], pred_masks.shape
                assert pred_boxes.shape[0] == pred_scores.shape[0], pred_scores.shape

                tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_segmentation(pred_masks=pred_masks, 
                                                                                                                       gt_masks=gt_masks, 
                                                                                                                       iou_threshold=0.5)
                df_multiorg.append([experiment_name, 
                           f'{str(test_data)}_{test_data.split}', im_ID, im_path,
                           'segmentation', backbone, ckpt_name, model_name, f'{optimal_thres:.2f}',
                           tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                
                tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient = pp.compute_metrics_detection(pred_boxes=pred_boxes, 
                                                                                                                    gt_boxes=boxes, 
                                                                                                                    iou_threshold=0.5)
                df_multiorg.append([experiment_name, 
                           f'{str(test_data)}_{test_data.split}', im_ID, im_path,
                           'detection', backbone, ckpt_name, model_name, f'{optimal_thres:.2f}',
                           tp, fp, fn, pq, precision, recall, f1_score, mean_iou, dice_coefficient])
                

df_multiorg = pd.DataFrame(data=df_multiorg, columns=[
    'exp_name', 'testset', 'im_ID', 'im_path', 'metric_type', 'backbone', 'ckpt_name', 'model_name', 'confidence_thres',
    'tp', 'fp', 'fn', 'pq', 'precision', 'recall', 'f1_score', 'mean_iou', 'dice_coefficient'
])
df_multiorg.to_csv(results_dir / f'organoID_test_{experiment_name}_correct_conf_thres_multiorg.csv')
df_multiorg
# Out:
# 0.85
# 100%|████████████████████████████████████████████████████████████████████████████| 12/12 [08:24<00:00, 42.00s/it]
#                                   exp_name           testset  \
# 0   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 1   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 2   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 3   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 4   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 5   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 6   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 7   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 8   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 9   ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 10  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 11  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 12  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 13  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 14  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 15  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 16  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 17  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 18  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 19  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 20  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 21  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 22  ablation_datasets_orgasegment_testdata  OrgaSegment_test
# 23  ablation_datasets_orgasegment_testdata  OrgaSegment_test
#
#                                            im_ID  \
# 0     0002_2013089_ckmbvhhhx0000345zlx7mhq1y_img
# 1     0002_2013089_ckmbvhhhx0000345zlx7mhq1y_img
# 2     0002_2423915_cknt06dr33pzv3b68t421bk27_img
# 3     0002_2423915_cknt06dr33pzv3b68t421bk27_img
# 4     0002_7071445_ckm384kvx8ib3345zzs8qewl4_img
# 5     0002_7071445_ckm384kvx8ib3345zzs8qewl4_img
# 6     0003_9960762_ckmdlvkmi14yv345z384v1grr_img
# 7     0003_9960762_ckmdlvkmi14yv345z384v1grr_img
# 8   20210727_11562_ckufm1p2h4vzp0y7jh0fyg2yo_img
# 9   20210727_11562_ckufm1p2h4vzp0y7jh0fyg2yo_img
# 10  20210727_11753_ckuf91aiz36dm0y9p2t9k5qoh_img
# 11  20210727_11753_ckuf91aiz36dm0y9p2t9k5qoh_img
# 12  20210727_12226_ckw3in2er4sqh10aofkm50w8l_img
# 13  20210727_12226_ckw3in2er4sqh10aofkm50w8l_img
# 14  20210727_16063_ckw3j7wet8qan0zc39rca87mv_img
# 15  20210727_16063_ckw3j7wet8qan0zc39rca87mv_img
# 16  20210727_18315_ckw3ky6ln8z8z0zbnfc0o1gam_img
# 17  20210727_18315_ckw3ky6ln8z8z0zbnfc0o1gam_img
# 18  20210727_26838_ckw3ig3xg5ngk0zbp0g7j7dqt_img
# 19  20210727_26838_ckw3ig3xg5ngk0zbp0g7j7dqt_img
# 20  20210727_33832_ckw3n2vrs9btz0zbn3jqgbv4y_img
# 21  20210727_33832_ckw3n2vrs9btz0zbn3jqgbv4y_img
# 22  20210727_37653_ckwggbhda5ql20z7n9eveah6i_img
# 23  20210727_37653_ckwggbhda5ql20z7n9eveah6i_img
#
#                                               im_path   metric_type  \
# 0   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 1   /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 2   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 3   /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 4   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 5   /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 6   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 7   /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 8   /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 9   /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 10  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 11  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 12  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 13  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 14  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 15  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 16  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 17  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 18  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 19  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 20  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 21  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
# 22  /ictstr01/groups/shared/users/lion.gleiter/org...  segmentation
# 23  /ictstr01/groups/shared/users/lion.gleiter/org...     detection
#
#      backbone                                          ckpt_name model_name  \
# 0   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 1   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 2   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 3   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 4   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 5   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 6   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 7   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 8   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 9   SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 10  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 11  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 12  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 13  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 14  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 15  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 16  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 17  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 18  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 19  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 20  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 21  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 22  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 23  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
#
#    confidence_thres  tp  fp  fn        pq  precision    recall  f1_score  \
# 0              0.85  58  10  12  0.713802   0.852941  0.828571  0.840580
# 1              0.85  58  10  12  0.000000   0.852941  0.828571  0.840580
# 2              0.85  45   9  31  0.554339   0.833333  0.592105  0.692308
# 3              0.85  44  10  32  0.000000   0.814815  0.578947  0.676923
# 4              0.85  36  10   8  0.670228   0.782609  0.818182  0.800000
# 5              0.85  34  12  10  0.000000   0.739130  0.772727  0.755556
# 6              0.85  32   7   4  0.748927   0.820513  0.888889  0.853333
# 7              0.85  32   7   4  0.000000   0.820513  0.888889  0.853333
# 8              0.85  41   9  11  0.612472   0.820000  0.788462  0.803922
# 9              0.85  41   9  11  0.000000   0.820000  0.788462  0.803922
# 10             0.85  26  10  24  0.465355   0.722222  0.520000  0.604651
# 11             0.85  24  12  26  0.000000   0.666667  0.480000  0.558140
# 12             0.85  83   6  66  0.585106   0.932584  0.557047  0.697479
# 13             0.85  72  17  77  0.000000   0.808989  0.483221  0.605042
# 14             0.85  62   8  66  0.512415   0.885714  0.484375  0.626263
# 15             0.85  59  11  69  0.000000   0.842857  0.460938  0.595960
# 16             0.85  48  18  27  0.611861   0.727273  0.640000  0.680851
# 17             0.85  45  21  30  0.000000   0.681818  0.600000  0.638298
# 18             0.85  50   6   9  0.639506   0.892857  0.847458  0.869565
# 19             0.85  48   8  11  0.000000   0.857143  0.813559  0.834783
# 20             0.85  65  13  83  0.500348   0.833333  0.439189  0.575221
# 21             0.85  56  22  92  0.000000   0.717949  0.378378  0.495575
# 22             0.85  58   2  28  0.699943   0.966667  0.674419  0.794521
# 23             0.85  56   4  30  0.000000   0.933333  0.651163  0.767123
#
#     mean_iou  dice_coefficient
# 0   0.849178          0.915115
# 1   0.755797          0.000000
# 2   0.800712          0.884356
# 3   0.689157          0.000000
# 4   0.837785          0.908992
# 5   0.802861          0.000000
# 6   0.877649          0.932064
# 7   0.796191          0.000000
# 8   0.761855          0.860754
# 9   0.796383          0.000000
# 10  0.769625          0.866359
# 11  0.718243          0.000000
# 12  0.838887          0.909545
# 13  0.742225          0.000000
# 14  0.818211          0.897531
# 15  0.720578          0.000000
# 16  0.898671          0.943691
# 17  0.757644          0.000000
# 18  0.735432          0.845321
# 19  0.774677          0.000000
# 20  0.869837          0.926969
# 21  0.721409          0.000000
# 22  0.880963          0.934474
# 23  0.752549          0.000000

# %%
metrics = df_multiorg.groupby(['exp_name', 'testset', 'metric_type', 'backbone', 'ckpt_name', 'model_name', #'confidence_thres'
                      ], as_index=False).agg(
    pq_mean = pd.NamedAgg('pq', 'mean'), 
    precision_mean = pd.NamedAgg('precision', 'mean'), 
    recall_mean = pd.NamedAgg('recall', 'mean'), 
    f1_score_mean = pd.NamedAgg('f1_score', 'mean'), 
    mean_iou_mean = pd.NamedAgg('mean_iou', 'mean'), 
    dice_coefficient_mean = pd.NamedAgg('dice_coefficient', 'mean')
)
metrics
# Out:
#                                  exp_name           testset   metric_type  \
# 0  ablation_datasets_orgasegment_testdata  OrgaSegment_test     detection
# 1  ablation_datasets_orgasegment_testdata  OrgaSegment_test  segmentation
#
#     backbone                                          ckpt_name model_name  \
# 0  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 1  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
#
#     pq_mean  precision_mean  recall_mean  f1_score_mean  mean_iou_mean  \
# 0  0.000000        0.796346     0.643738       0.702103       0.752310
# 1  0.609525        0.839171     0.673225       0.736558       0.828234
#
#    dice_coefficient_mean
# 0               0.000000
# 1               0.902098

# %%
metrics = df_multiorg.groupby(['exp_name', 'testset', 'metric_type', 'backbone', 'ckpt_name', 'model_name', #'confidence_thres'
                      ], as_index=False).agg(
    pq_mean = pd.NamedAgg('pq', 'mean'), 
    precision_mean = pd.NamedAgg('precision', 'mean'), 
    recall_mean = pd.NamedAgg('recall', 'mean'), 
    f1_score_mean = pd.NamedAgg('f1_score', 'mean'), 
    mean_iou_mean = pd.NamedAgg('mean_iou', 'mean'), 
    dice_coefficient_mean = pd.NamedAgg('dice_coefficient', 'mean')
)
metrics
# Out:
#                                  exp_name           testset   metric_type  \
# 0  ablation_datasets_orgasegment_testdata  OrgaSegment_test     detection
# 1  ablation_datasets_orgasegment_testdata  OrgaSegment_test  segmentation
#
#     backbone                                          ckpt_name model_name  \
# 0  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
# 1  SAM_large  DetectionHead_SAM_large_OrganoID_train_MultiOr...  dataset_5
#
#     pq_mean  precision_mean  recall_mean  f1_score_mean  mean_iou_mean  \
# 0  0.000000        0.919962     0.508474       0.634509       0.769109
# 1  0.536625        0.934416     0.514000       0.642278       0.838839
#
#    dice_coefficient_mean
# 0               0.000000
# 1               0.908846

# %%
metrics.to_csv(results_dir / f'organoID_test_{experiment_name}_correct_conf_thres_aggregated.csv')
# metrics.head(40)

# %%
print(f'organoID_test_{experiment_name}_correct_conf_thres_aggregated')
# Out:
# organoID_test_ablation_datasets_new_correct_conf_thres_aggregated

# %%
pq_metrics = metrics[metrics.metric_type == 'segmentation'].pivot(
    index='model_name', columns='testset', values='pq_mean'
).loc[['dataset_0', 'dataset_2', 'dataset_5', 'dataset_10', 'dataset_20'], :]
# pq_metrics.to_csv(results_dir / f'{experiment_name}_PQ.csv')
pq_metrics #.loc[['MicroSAM_base_best', 'SAM2_large_best', 'SAM_large_best', 'SAM_base_best'], :]
# Out:
# testset     OrganoID_test  OrganoID_test_ACC  OrganoID_test_C  \
# model_name
# dataset_0        0.589984           0.614581         0.721033
# dataset_2        0.598743           0.636255         0.709771
# dataset_5        0.600654           0.641483         0.727169
# dataset_10       0.579946           0.589522         0.717435
# dataset_20       0.566612           0.542839         0.737078
#
# testset     OrganoID_test_Lung  OrganoID_test_mouse
# model_name
# dataset_0             0.834300             0.605430
# dataset_2             0.829018             0.600368
# dataset_5             0.821686             0.637314
# dataset_10            0.825609             0.585154
# dataset_20            0.779445             0.577615
